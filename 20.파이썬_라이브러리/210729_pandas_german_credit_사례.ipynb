# %% [markdown]
# ##  ( German_credit 실습  )
# 1. german_credit.csv 화일을 읽어서 DataFrame을 만든다 (german)
# 2. 데이터 확인 기본 실행
#    - 첫 5행 데이터 보기
#    - 마지막 5행 데이터 보기
#    - 데이터는 총 몇건 인가?  컬럼은 몇개인가?
#    - 전체 컬럼명은?
#    - 컬럼명중에서 앞에 5개를 리스트로 만들기 ( sel_column )
#    - 데이터프레임 전체 구조(정보)는?
#    - 결측치를 확인?
#    - 데이터 요약 통계량 보기?
#    - Purpose 컬럼(변수)의 데이터는 어떻게 구성되어 있나? (구성별 카운트)
#    - Purpose 컬럼 데이터를 value순으로 정렬 (내림차순)
#    - Purpose 컬럼 데이터를 index순으로 정렬 (오름차순)
# 3. german 에서 Creditability, Duration of Credit (month), Purpose, Credit Amount 컬럼으로 구성된 german_sample 만들기
#    - german_sample min(), max(), mean() 정보 보기

# %%
import pandas as pd

german = pd.read_csv("c:/jswoo/german_credit.csv")
german.head()
# Out:
#    Creditability  Account Balance  Duration of Credit (month)  \
# 0              1                1                          18
# 1              1                1                           9
# 2              1                2                          12
# 3              1                1                          12
# 4              1                1                          12
#
#    Payment Status of Previous Credit  Purpose  Credit Amount  \
# 0                                  4        2           1049
# 1                                  4        0           2799
# 2                                  2        9            841
# 3                                  4        0           2122
# 4                                  4        0           2171
#
#    Value Savings/Stocks  Length of current employment  Instalment per cent  \
# 0                     1                             2                    4
# ...

# %%
german.tail()
# Out:
#      Creditability  Account Balance  Duration of Credit (month)  \
# 995              0                1                          24
# 996              0                1                          24
# 997              0                4                          21
# 998              0                2                          12
# 999              0                1                          30
#
#      Payment Status of Previous Credit  Purpose  Credit Amount  \
# 995                                  2        3           1987
# 996                                  2        0           2303
# 997                                  4        0          12680
# 998                                  2        3           6468
# 999                                  2        2           6350
#
#      Value Savings/Stocks  Length of current employment  Instalment per cent  \
# 995                     1                             3                    2
# ...

# %%
german.shape
# Out:
# (1000, 21)

# %%
german.columns
# Out:
# Index(['Creditability', 'Account Balance', 'Duration of Credit (month)',
#        'Payment Status of Previous Credit', 'Purpose', 'Credit Amount',
#        'Value Savings/Stocks', 'Length of current employment',
#        'Instalment per cent', 'Sex & Marital Status', 'Guarantors',
#        'Duration in Current address', 'Most valuable available asset',
#        'Age (years)', 'Concurrent Credits', 'Type of apartment',
#        'No of Credits at this Bank', 'Occupation', 'No of dependents',
#        'Telephone', 'Foreign Worker'],
#       dtype='object')

# %%
german.columns[:5]
# Out:
# Index(['Creditability', 'Account Balance', 'Duration of Credit (month)',
#        'Payment Status of Previous Credit', 'Purpose'],
#       dtype='object')

# %%
german.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Creditability                      1000 non-null   int64
#  1   Account Balance                    1000 non-null   int64
#  2   Duration of Credit (month)         1000 non-null   int64
#  3   Payment Status of Previous Credit  1000 non-null   int64
#  4   Purpose                            1000 non-null   int64
#  5   Credit Amount                      1000 non-null   int64
#  6   Value Savings/Stocks               1000 non-null   int64
#  7   Length of current employment       1000 non-null   int64
#  8   Instalment per cent                1000 non-null   int64
#  9   Sex & Marital Status               1000 non-null   int64
#  10  Guarantors                         1000 non-null   int64
# ...

# %%
german.isnull().sum()
# Out:
# Creditability                        0
# Account Balance                      0
# Duration of Credit (month)           0
# Payment Status of Previous Credit    0
# Purpose                              0
# Credit Amount                        0
# Value Savings/Stocks                 0
# Length of current employment         0
# Instalment per cent                  0
# Sex & Marital Status                 0
# Guarantors                           0
# Duration in Current address          0
# Most valuable available asset        0
# Age (years)                          0
# Concurrent Credits                   0
# Type of apartment                    0
# No of Credits at this Bank           0
# Occupation                           0
# No of dependents                     0
# Telephone                            0
# Foreign Worker                       0
# dtype: int64

# %%
german.describe()
# Out:
#        Creditability  Account Balance  Duration of Credit (month)  \
# count    1000.000000      1000.000000                 1000.000000
# mean        0.700000         2.577000                   20.903000
# std         0.458487         1.257638                   12.058814
# min         0.000000         1.000000                    4.000000
# 25%         0.000000         1.000000                   12.000000
# 50%         1.000000         2.000000                   18.000000
# 75%         1.000000         4.000000                   24.000000
# max         1.000000         4.000000                   72.000000
#
#        Payment Status of Previous Credit      Purpose  Credit Amount  \
# count                         1000.00000  1000.000000     1000.00000
# mean                             2.54500     2.828000     3271.24800
# std                              1.08312     2.744439     2822.75176
# min                              0.00000     0.000000      250.00000
# ...

# %%
german["Purpose"]
# Out:
# 0      2
# 1      0
# 2      9
# 3      0
# 4      0
#       ..
# 995    3
# 996    0
# 997    0
# 998    3
# 999    2
# Name: Purpose, Length: 1000, dtype: int64

# %%
german.Purpose
# Out:
# 0      2
# 1      0
# 2      9
# 3      0
# 4      0
#       ..
# 995    3
# 996    0
# 997    0
# 998    3
# 999    2
# Name: Purpose, Length: 1000, dtype: int64

# %%
german["Purpose"].value_counts()
# Out:
# 3     280
# 0     234
# 2     181
# 1     103
# 9      97
# 6      50
# 5      22
# 4      12
# 10     12
# 8       9
# Name: Purpose, dtype: int64

# %%
german.Purpose.value_counts().sort_index()
# Out:
# 0     234
# 1     103
# 2     181
# 3     280
# 4      12
# 5      22
# 6      50
# 8       9
# 9      97
# 10     12
# Name: Purpose, dtype: int64

# %%
german["Purpose"].value_counts().sort_values(ascending=False)
# Out:
# 3     280
# 0     234
# 2     181
# 1     103
# 9      97
# 6      50
# 5      22
# 4      12
# 10     12
# 8       9
# Name: Purpose, dtype: int64

# %%
german_sample = german[["Creditability","Duration of Credit (month)","Purpose","Credit Amount"]]
german_sample.head()
# Out:
#    Creditability  Duration of Credit (month)  Purpose  Credit Amount
# 0              1                          18        2           1049
# 1              1                           9        0           2799
# 2              1                          12        9            841
# 3              1                          12        0           2122
# 4              1                          12        0           2171

# %%
german_sample.max()
# Out:
# Creditability                     1
# Duration of Credit (month)       72
# Purpose                          10
# Credit Amount                 18424
# dtype: int64

# %%
german_sample.min()
# Out:
# Creditability                   0
# Duration of Credit (month)      4
# Purpose                         0
# Credit Amount                 250
# dtype: int64

# %%
german_sample.mean()
# Out:
# Creditability                    0.700
# Duration of Credit (month)      20.903
# Purpose                          2.828
# Credit Amount                 3271.248
# dtype: float64

# %%
german_sample.describe()
# Out:
#        Creditability  Duration of Credit (month)      Purpose  Credit Amount
# count    1000.000000                 1000.000000  1000.000000     1000.00000
# mean        0.700000                   20.903000     2.828000     3271.24800
# std         0.458487                   12.058814     2.744439     2822.75176
# min         0.000000                    4.000000     0.000000      250.00000
# 25%         0.000000                   12.000000     1.000000     1365.50000
# 50%         1.000000                   18.000000     2.000000     2319.50000
# 75%         1.000000                   24.000000     3.000000     3972.25000
# max         1.000000                   72.000000    10.000000    18424.00000

# %%
german_sample1 = german[["Duration of Credit (month)","Credit Amount","Age (years)"]]
german_sample1.head()
# Out:
#    Duration of Credit (month)  Credit Amount  Age (years)
# 0                          18           1049           21
# 1                           9           2799           36
# 2                          12            841           23
# 3                          12           2122           39
# 4                          12           2171           38

# %%
german.columns
# Out:
# Index(['Creditability', 'Account Balance', 'Duration of Credit (month)',
#        'Payment Status of Previous Credit', 'Purpose', 'Credit Amount',
#        'Value Savings/Stocks', 'Length of current employment',
#        'Instalment per cent', 'Sex & Marital Status', 'Guarantors',
#        'Duration in Current address', 'Most valuable available asset',
#        'Age (years)', 'Concurrent Credits', 'Type of apartment',
#        'No of Credits at this Bank', 'Occupation', 'No of dependents',
#        'Telephone', 'Foreign Worker'],
#       dtype='object')

# %%
german_sample1.corr()
# Out:
#                             Duration of Credit (month)  Credit Amount  \
# Duration of Credit (month)                    1.000000       0.624988
# Credit Amount                                 0.624988       1.000000
# Age (years)                                  -0.037550       0.032273
#
#                             Age (years)
# Duration of Credit (month)    -0.037550
# Credit Amount                  0.032273
# Age (years)                    1.000000

# %%
german_sample1.cov()
# Out:
#                             Duration of Credit (month)  Credit Amount  \
# Duration of Credit (month)                  145.415006   2.127401e+04
# Credit Amount                             21274.007063   7.967927e+06
# Age (years)                                  -5.140567   1.034203e+03
#
#                             Age (years)
# Duration of Credit (month)    -5.140567
# Credit Amount               1034.202787
# Age (years)                  128.883119

# %%
german_grouped = german["Credit Amount"].groupby(german["Type of apartment"])

# %%
german_grouped.mean()
# Out:
# Type of apartment
# 1    3122.553073
# 2    3067.257703
# 3    4881.205607
# Name: Credit Amount, dtype: float64

# %%
list(german_grouped)[0]
# Out:
# (1,
#  0      1049
#  1      2799
#  2       841
#  3      2122
#  5      2241
#         ...
#  983    1882
#  989    2718
#  993    3966
#  994    6199
#  995    1987
#  Name: Credit Amount, Length: 179, dtype: int64)

# %%
german_grouped.mean()
# Out:
# Type of apartment
# 1    3122.553073
# 2    3067.257703
# 3    4881.205607
# Name: Credit Amount, dtype: float64

# %%
german_group2 = german["Credit Amount"].groupby([german["Purpose"],german["Type of apartment"]])
german_group2

# %%
list(german_group2)[0]
# Out:
# ((0, 1),
#  1      2799
#  3      2122
#  5      2241
#  10     3905
#  20     3676
#  45     1216
#  89     1965
#  103    7432
#  115    6260
#  305    1469
#  319    1204
#  320    1597
#  326    1418
#  333    1283
#  343    3577
#  368    1403
#  383     276
#  464    7472
#  514    3186
#  550    2002
#  593    1193
#  714    3518
#  733    2511
#  755     950
#  790    1778
#  801    1285
#  802    1371
#  805    1207
#  827    4843
#  866    1295
#  883    1264
#  884    2631
#  897    2570
#  922    1442
#  932    1223
#  934    2625
#  935    2235
#  960    6761
#  989    2718
#  993    3966
#  Name: Credit Amount, dtype: int64)

# %%
german_group2.mean()
# Out:
# Purpose  Type of apartment
# 0        1                    2597.225000
#          2                    2811.024242
#          3                    5138.689655
# 1        1                    5037.086957
#          2                    4915.222222
#          3                    6609.923077
# 2        1                    2727.354167
#          2                    3107.450820
#          3                    4100.181818
# 3        1                    2199.763158
#          2                    2540.533040
#          3                    2417.333333
# 4        1                    1255.500000
#          2                    1546.500000
# 5        1                    1522.000000
#          2                    2866.000000
#          3                    2750.666667
# 6        1                    3156.444444
#          2                    2492.423077
#          3                    4387.266667
# 8        1                     902.000000
#          2                    1243.875000
# ...

# %%
german_sample3 = german[["Type of apartment","Sex & Marital Status","Credit Amount"]]
german_sample3.head(3)
# Out:
#    Type of apartment  Sex & Marital Status  Credit Amount
# 0                  1                     2           1049
# 1                  1                     3           2799
# 2                  1                     2            841

# %%
german_grouped3 = german_sample3.groupby("Type of apartment")
german_grouped3

# %%
for type1, group in german_grouped3:
    print("type1")
    print(group.head(3))
# Out:
# type1
#    Type of apartment  Sex & Marital Status  Credit Amount
# 0                  1                     2           1049
# 1                  1                     3           2799
# 2                  1                     2            841
# type1
#    Type of apartment  Sex & Marital Status  Credit Amount
# 4                  2                     3           2171
# 6                  2                     3           3398
# 7                  2                     3           1361
# type1
#     Type of apartment  Sex & Marital Status  Credit Amount
# 29                  3                     3           4796
# 44                  3                     3           1239
# 69                  3                     3           2032

# %%
german_group3 = german_sample3.groupby(["Type of apartment","Sex & Marital Status"])
german_group3

# %%
list(german_group3)[0]
# Out:
# ((1, 1),
#       Type of apartment  Sex & Marital Status  Credit Amount
#  369                  1                     1           3021
#  777                  1                     1           3384
#  797                  1                     1           2319
#  857                  1                     1           2302
#  932                  1                     1           1223
#  956                  1                     1           2767)

# %%
for (aa,bb), cc in german_group3:
    print("aa = ", aa, " ** ", bb)
    print("cc = ", cc)
    break
# Out:
# aa =  1  **  1
# cc =       Type of apartment  Sex & Marital Status  Credit Amount
# 369                  1                     1           3021
# 777                  1                     1           3384
# 797                  1                     1           2319
# 857                  1                     1           2302
# 932                  1                     1           1223
# 956                  1                     1           2767

# %%
for (type1, sex), group in german_sample3.groupby(["Type of apartment","Sex & Marital Status"]):
    print(type1, sex)
    print(group.head(3))
# Out:
# 1 1
#      Type of apartment  Sex & Marital Status  Credit Amount
# 369                  1                     1           3021
# 777                  1                     1           3384
# 797                  1                     1           2319
# 1 2
#    Type of apartment  Sex & Marital Status  Credit Amount
# 0                  1                     2           1049
# 2                  1                     2            841
# 9                  1                     2           3758
# 1 3
#    Type of apartment  Sex & Marital Status  Credit Amount
# 1                  1                     3           2799
# 3                  1                     3           2122
# 5                  1                     3           2241
# 1 4
#     Type of apartment  Sex & Marital Status  Credit Amount
# 11                  1                     4           6187
# 14                  1                     4           1936
# 17                  1                     4           3213
# ...

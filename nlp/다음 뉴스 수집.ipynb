# %% [markdown]
# # 크롤링
# - 오늘 날짜부터 -n일차 까지 다음뉴스의 데이터를 긁어 오는 작업으로 시작합니다.
#
# - 날짜를 거꾸로 수집을 합니다.
#
# - 오늘로부터 며칠 전까지 이런식으로
#
# - 다음 랭킹뉴스에서 50개까지 url을 긁어온 뒤
#
# - 다시 for문을 이용해서 url을 접속해서 content를 긁어서 저장합니다.
#
# - 이 함수의 역할은 여기까지입니다.

# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
from datetime import datetime

# %%
def daum(dates):

    # 다음뉴스 헤드라인 긁어오기
    files = pd.DataFrame()
    for date in dates:
        http=[]
        print(date,'', 'Daum 접속 중')
        httz = 'https://media.daum.net/ranking/popular/?regDate={}'.format(date)
        res = requests.get(httz)
        soup = BeautifulSoup(res.content, 'html.parser')
        body = soup.select('#mArticle > div.rank_news > ul.list_news2')
        body = body[0].find_all('a')


        for i in range(len(body)):
            t = body[i].get('href')
            http.append(t)

        # 중복제거
        http = list(set(http))
        
        for i in range(len(http)):
            res = requests.get(http[i])
            soup = BeautifulSoup(res.content, 'html.parser')
            body = soup.select('.article_view')[0]

            files = files.append(pd.DataFrame({
                'date':date,
                'title': soup.find('div', attrs={'class': 'head_view'}).h3.text,
                'content': " ".join(p.get_text() for p in body.find_all('p')),
                'link': http[i]
            }, index=[i]))
        time.sleep(15)

        # 텍스트파일에 댓글 저장하기
    files.to_csv('다음뉴스종합.csv',index=False,encoding='utf-8')
    print('파일 저장 완료!')

# %%
# 현재로 부터 며칠 전까지 수집할 것인지 확인
days = 1

dates = [int(datetime.today().strftime('%Y%m%d')) - i for i in range(days)]
daum(dates)
# Out:
# 20211026  Daum 접속 중
# 파일 저장 완료!

# %% [markdown]
# # 데이터 수집 끝
# # 뉴스 content의 내용을 tfidf를 이용하여 유사도를 분석합니다.

# %% [markdown]
# <pre>
# tfidf를 모르시면 한번 확인하시길 바랍니다.
# 이후 코드입니다.
# 원래는 뉴스데이터 원본을 바로 Tf-idf를 이용하고, 바로 코사인유사도를 이용하여 분석하였습니다.
# 하지만 조금 변경해서 명사추출로 먼저 데이터를 정제한 후에 모델에 입력합니다.
# 그 이후에 Tf-idf -> 코사인유사도로 문서간의 유사도를 분석합니다.

# %%
self의 의미
https://velog.io/@magnoliarfsit/RePython-1.-self-%EC%9D%B4%ED%95%B4%ED%95%98%EA%B8%B0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from ckonlpy.tag import Twitter

#dataframe에 null값이 있는 경우 공백을 넣어 null값 제거
class TFIDF:
    def __init__(self,okky_data,word_dictionary):
        self.okky_data = okky_data
        self.word_dictionary = word_dictionary
        
        self.okky_data['noun_content'] = self.noun_extraction(self.okky_data['content'],
                                                         self.word_dictionary)

    # 전처리작업 (명사추출)
    def noun_extraction(self,text2,word_dictionary):
        t = Twitter()
        t.add_dictionary(word_dictionary, 'Noun')

        tokens = []

        for i in range(len(text2)):
            tokens_ko = ''
            noun = t.nouns(text2[i])
            for n in noun:
                tokens_ko = tokens_ko + ' ' + n
            # 공백삭제
            tokens_ko = tokens_ko[1:]
            tokens.append(tokens_ko)
        return tokens
    
    # Null 제거 함수
    def avoid_null(self,data, header):
        data[header] = data[header].fillna('')
        return data[header]

    # Content의 tf-idf를 이용하여 유사도 확인
    def fit_tfidf(self):
        #content 데이터의 내용을 null 없이 가져옴
        self.okky_data['noun_content'] = self.avoid_null(self.okky_data, 'noun_content')

        #tf-idf계산 후 출력
        tfidfVectorizer = TfidfVectorizer()
        self.tfidf_metrix_of_tit = tfidfVectorizer.fit_transform(self.okky_data['noun_content'])
        return self.tfidf_metrix_of_tit


    #입력되는 train의 질문과 질문 데이터셋의 코사인유사도 값 중 상위 50개 질문목록을 가져오는 함수
    def top10_indices(self,data, q_num):
        #입력된 데이터의 코사인유사도 계산
        cos_sim = linear_kernel(data, data)

        cos_sim_score = list(enumerate(cos_sim[q_num])) 
        cos_sim_score = sorted(cos_sim_score, key = lambda x : x[1], reverse = True)
        #상위 10개 항목을 가져옴
        score = cos_sim_score[1:11]
        tag_indices = [i[0] for i in score]

        return tag_indices

# %% [markdown]
# word_dictionary는 명사추출에 앞서서 원하는 명사를 추출하기 위해서 사전 역할을 합니다.
#
# 위에서 긁어온 데이터를 다시 불러서 진행합니다.

# %%
word_dictionary = ['전세집']

okky_data = pd.read_csv(r'다음뉴스종합.csv', encoding = "utf-8", low_memory = False)

# %% [markdown]
# 데이터를 입력하면 명사 추출까지는 자동으로 입력하고
#
# 그 이후 fit_tfidf 메서드를 불러서 유사도 metrix를 저장합니다.

# %%
TFIDF = TFIDF(okky_data,word_dictionary)

data_tit = TFIDF.fit_tfidf()
# Out:
# c:\ai\pythonproject\venv\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %% [markdown]
# 마지막으로 코사인유사도로 순위가 나타난 문서들을 출력할 차례입니다.

# %%
# 50개까지만 출력합니다.
count = 50

for i in range(len(okky_data[:count])):
    print(i, '/', len(okky_data))
    #질문 제목과 데이터셋의 유사도를 10위까지 가져옴
    tit_10_q = okky_data['content'].iloc[TFIDF.top10_indices(data_tit, i)]
    print(str(i),"번 뉴스와 유사한 내용을 가진 뉴스목록\n", tit_10_q)
# Out:
# 0 / 50
# 0 번 뉴스와 유사한 내용을 가진 뉴스목록
#  9     왕이 중국 외교담당 국무위원 겸 외교부장이 일본을 향해 “역사 인식과 대만 등은 중...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# 28     초기에 발견하기 어렵기 때문에 '침묵의 살인자'라 불리는 췌장암에 걸리는 젊은 여...
# 38     (서울=뉴스1) 김규빈 기자,음상준 기자,권영미 기자,이형진 기자,강승지 기자 =...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# 43     [이데일리 박지혜 기자] 대한민국 제13대 대통령을 지낸 노태우 전 대통령이 26...
# 12     (시카고=연합뉴스) 김현 통신원 = 미국에서 많은 의문을 남긴 채 실종됐던 전도유...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 36      # 내년 4월 결혼식을 위해 웨딩홀을 예약하려던 서울 서초동의 김모(32)씨. ...
# Name: content, dtype: object
# 1 / 50
# 1 번 뉴스와 유사한 내용을 가진 뉴스목록
#  37     (서울=뉴스1) 한유주 기자,최현만 기자 = 고발사주 의혹의 핵심인물이자 텔레그램...
# 27     김용판 의원은 이날 '돈다발' 사진과 관련해 "민주당은 돈다발 사진이 박철민 페이...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 48    기사내용 요약 공수처의 손준성 전 정책관 구속영장 청구 관련  변협 "방어권 보장 ...
# 33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# 41     국민의힘 대선 후보를 결정하기 위한 본경선 여론조사 문항이 결정됐다. '가상 양자...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 46    기사내용 요약 검찰, 김만배 남욱 소환 조사 이어가 '박영수 딸 특혜" 질문에 김만...
# Name: content, dtype: object
# 2 / 50
# 2 번 뉴스와 유사한 내용을 가진 뉴스목록
#  30     독립운동가 안중근 의사의 조카며느리 고(故) 박태정 여사가 생활고로 삼일장도 치르...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 29     노태우 전 대통령이 26일 별세했다. 향년 89세. 이날은 박정희 전 대통령의 기...
# 36      # 내년 4월 결혼식을 위해 웨딩홀을 예약하려던 서울 서초동의 김모(32)씨. ...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 12     (시카고=연합뉴스) 김현 통신원 = 미국에서 많은 의문을 남긴 채 실종됐던 전도유...
# 6      지난 21일 누리호가 우주로 향할 준비를 하고 있을 무렵. 발사대에서 20km 떨...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# 28     초기에 발견하기 어렵기 때문에 '침묵의 살인자'라 불리는 췌장암에 걸리는 젊은 여...
# Name: content, dtype: object
# 3 / 50
# 3 번 뉴스와 유사한 내용을 가진 뉴스목록
#  36      # 내년 4월 결혼식을 위해 웨딩홀을 예약하려던 서울 서초동의 김모(32)씨. ...
# 5      신종 코로나바이러스 감염증(코로나19) 확산에 대처하는 중국의 해법은 하나다. 지...
# 38     (서울=뉴스1) 김규빈 기자,음상준 기자,권영미 기자,이형진 기자,강승지 기자 =...
# 9     왕이 중국 외교담당 국무위원 겸 외교부장이 일본을 향해 “역사 인식과 대만 등은 중...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 13     "가계부채 대책이 실행되기 전에 급매라도 잡아야 하나요?", "내년부터 시행이면 ...
# 8      올해 겨울은 예상치 못한 한파가 갑자기 찾아오는 등 큰 폭의 기온 변화가 예상된다...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 34     (천안=뉴스1) 이시우 기자 = 충남 천안의 한 아파트 지하 주차장 화재로 차량 ...
# Name: content, dtype: object
# 4 / 50
# 4 번 뉴스와 유사한 내용을 가진 뉴스목록
#  15     (서울=연합뉴스) 이준서 기자 = 대한민국 제13대 대통령을 지낸 노태우 전 대통...
# 25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 29     노태우 전 대통령이 26일 별세했다. 향년 89세. 이날은 박정희 전 대통령의 기...
# 21     노 전 대통령은 1932년 12월4일 경북 달성군 공산면 신용리(현 대구 동구 신...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 47     [아시아경제 양낙규 군사전문기자]26일 별세한 노태우 전 대통령이 국립현충원에 안...
# 43     [이데일리 박지혜 기자] 대한민국 제13대 대통령을 지낸 노태우 전 대통령이 26...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# Name: content, dtype: object
# 5 / 50
# 5 번 뉴스와 유사한 내용을 가진 뉴스목록
#  3      (서울=뉴스1) 이형진 기자 = 방역당국이 오는 28일 신종 코로나바이러스 감염증...
# 36      # 내년 4월 결혼식을 위해 웨딩홀을 예약하려던 서울 서초동의 김모(32)씨. ...
# 9     왕이 중국 외교담당 국무위원 겸 외교부장이 일본을 향해 “역사 인식과 대만 등은 중...
# 38     (서울=뉴스1) 김규빈 기자,음상준 기자,권영미 기자,이형진 기자,강승지 기자 =...
# 16    기사내용 요약 농식품부, 단계적 일상회복 맞춰 외식 쿠폰 확대 잔여 예산 180억 ...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# 41     국민의힘 대선 후보를 결정하기 위한 본경선 여론조사 문항이 결정됐다. '가상 양자...
# 8      올해 겨울은 예상치 못한 한파가 갑자기 찾아오는 등 큰 폭의 기온 변화가 예상된다...
# 15     (서울=연합뉴스) 이준서 기자 = 대한민국 제13대 대통령을 지낸 노태우 전 대통...
# 13     "가계부채 대책이 실행되기 전에 급매라도 잡아야 하나요?", "내년부터 시행이면 ...
# Name: content, dtype: object
# 6 / 50
# 6 번 뉴스와 유사한 내용을 가진 뉴스목록
#  27     김용판 의원은 이날 '돈다발' 사진과 관련해 "민주당은 돈다발 사진이 박철민 페이...
# 28     초기에 발견하기 어렵기 때문에 '침묵의 살인자'라 불리는 췌장암에 걸리는 젊은 여...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 1            손 검사는 지난해 4월 대검찰청 수사정보정책관 재직 당시 국회의원 후보...
# 36      # 내년 4월 결혼식을 위해 웨딩홀을 예약하려던 서울 서초동의 김모(32)씨. ...
# 43     [이데일리 박지혜 기자] 대한민국 제13대 대통령을 지낸 노태우 전 대통령이 26...
# 46    기사내용 요약 검찰, 김만배 남욱 소환 조사 이어가 '박영수 딸 특혜" 질문에 김만...
# 38     (서울=뉴스1) 김규빈 기자,음상준 기자,권영미 기자,이형진 기자,강승지 기자 =...
# 19     대구에서도 윤석열 국민의힘 대선주자의 전두환 옹호 발언과 개사과 사진을 비판하는 ...
# 14     - 김종인과 만남 거절당했다는 것은 거짓말 - 김종인, 경선에서 만날 생각 없어 ...
# Name: content, dtype: object
# 7 / 50
# 7 번 뉴스와 유사한 내용을 가진 뉴스목록
#  17     [이데일리 송혜수 기자] 현직 20대 여성 순경이 만취 상태로 오토바이를 몰고 상...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 34     (천안=뉴스1) 이시우 기자 = 충남 천안의 한 아파트 지하 주차장 화재로 차량 ...
# 12     (시카고=연합뉴스) 김현 통신원 = 미국에서 많은 의문을 남긴 채 실종됐던 전도유...
# 48    기사내용 요약 공수처의 손준성 전 정책관 구속영장 청구 관련  변협 "방어권 보장 ...
# 46    기사내용 요약 검찰, 김만배 남욱 소환 조사 이어가 '박영수 딸 특혜" 질문에 김만...
# 37     (서울=뉴스1) 한유주 기자,최현만 기자 = 고발사주 의혹의 핵심인물이자 텔레그램...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# Name: content, dtype: object
# 8 / 50
# 8 번 뉴스와 유사한 내용을 가진 뉴스목록
#  34     (천안=뉴스1) 이시우 기자 = 충남 천안의 한 아파트 지하 주차장 화재로 차량 ...
# 45     (서울=연합뉴스) 전명훈 기자 = 2019년 미국 동부 해안에서 균형을 잃고 쓰러...
# 13     "가계부채 대책이 실행되기 전에 급매라도 잡아야 하나요?", "내년부터 시행이면 ...
# 5      신종 코로나바이러스 감염증(코로나19) 확산에 대처하는 중국의 해법은 하나다. 지...
# 1            손 검사는 지난해 4월 대검찰청 수사정보정책관 재직 당시 국회의원 후보...
# 3      (서울=뉴스1) 이형진 기자 = 방역당국이 오는 28일 신종 코로나바이러스 감염증...
# 9     왕이 중국 외교담당 국무위원 겸 외교부장이 일본을 향해 “역사 인식과 대만 등은 중...
# 28     초기에 발견하기 어렵기 때문에 '침묵의 살인자'라 불리는 췌장암에 걸리는 젊은 여...
# 16    기사내용 요약 농식품부, 단계적 일상회복 맞춰 외식 쿠폰 확대 잔여 예산 180억 ...
# 12     (시카고=연합뉴스) 김현 통신원 = 미국에서 많은 의문을 남긴 채 실종됐던 전도유...
# Name: content, dtype: object
# 9 / 50
# 9 번 뉴스와 유사한 내용을 가진 뉴스목록
#  5      신종 코로나바이러스 감염증(코로나19) 확산에 대처하는 중국의 해법은 하나다. 지...
# 38     (서울=뉴스1) 김규빈 기자,음상준 기자,권영미 기자,이형진 기자,강승지 기자 =...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# 0     나루히토(德仁) 일왕의 조카인 마코(眞子·30) 공주가 26일 약혼자 고무로 게이(...
# 3      (서울=뉴스1) 이형진 기자 = 방역당국이 오는 28일 신종 코로나바이러스 감염증...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 8      올해 겨울은 예상치 못한 한파가 갑자기 찾아오는 등 큰 폭의 기온 변화가 예상된다...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# Name: content, dtype: object
# 10 / 50
# 10 번 뉴스와 유사한 내용을 가진 뉴스목록
#  41     국민의힘 대선 후보를 결정하기 위한 본경선 여론조사 문항이 결정됐다. '가상 양자...
# 22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 14     - 김종인과 만남 거절당했다는 것은 거짓말 - 김종인, 경선에서 만날 생각 없어 ...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# Name: content, dtype: object
# 11 / 50
# 11 번 뉴스와 유사한 내용을 가진 뉴스목록
#  33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# 41     국민의힘 대선 후보를 결정하기 위한 본경선 여론조사 문항이 결정됐다. '가상 양자...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 14     - 김종인과 만남 거절당했다는 것은 거짓말 - 김종인, 경선에서 만날 생각 없어 ...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# Name: content, dtype: object
# 12 / 50
# 12 번 뉴스와 유사한 내용을 가진 뉴스목록
#  7     비리 의혹 목사 비호 의혹 방배서 경찰, 관련 취재 온 기자에 물리력 행사…휴대전화...
# 17     [이데일리 송혜수 기자] 현직 20대 여성 순경이 만취 상태로 오토바이를 몰고 상...
# 45     (서울=연합뉴스) 전명훈 기자 = 2019년 미국 동부 해안에서 균형을 잃고 쓰러...
# 34     (천안=뉴스1) 이시우 기자 = 충남 천안의 한 아파트 지하 주차장 화재로 차량 ...
# 28     초기에 발견하기 어렵기 때문에 '침묵의 살인자'라 불리는 췌장암에 걸리는 젊은 여...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 0     나루히토(德仁) 일왕의 조카인 마코(眞子·30) 공주가 26일 약혼자 고무로 게이(...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 8      올해 겨울은 예상치 못한 한파가 갑자기 찾아오는 등 큰 폭의 기온 변화가 예상된다...
# Name: content, dtype: object
# 13 / 50
# 13 번 뉴스와 유사한 내용을 가진 뉴스목록
#  36      # 내년 4월 결혼식을 위해 웨딩홀을 예약하려던 서울 서초동의 김모(32)씨. ...
# 8      올해 겨울은 예상치 못한 한파가 갑자기 찾아오는 등 큰 폭의 기온 변화가 예상된다...
# 3      (서울=뉴스1) 이형진 기자 = 방역당국이 오는 28일 신종 코로나바이러스 감염증...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 16    기사내용 요약 농식품부, 단계적 일상회복 맞춰 외식 쿠폰 확대 잔여 예산 180억 ...
# 34     (천안=뉴스1) 이시우 기자 = 충남 천안의 한 아파트 지하 주차장 화재로 차량 ...
# 20      [서울=뉴시스] 류현주 기자 = 프로포폴 불법 투약 혐의를 받는 이재용 삼성전자...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# 25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# Name: content, dtype: object
# 14 / 50
# 14 번 뉴스와 유사한 내용을 가진 뉴스목록
#  22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 41     국민의힘 대선 후보를 결정하기 위한 본경선 여론조사 문항이 결정됐다. '가상 양자...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 10    기사내용 요약 홍준표측, 당원 투표 중 ARS전화때 본인인증 절차 도입 요구 선관위...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# Name: content, dtype: object
# 15 / 50
# 15 번 뉴스와 유사한 내용을 가진 뉴스목록
#  29     노태우 전 대통령이 26일 별세했다. 향년 89세. 이날은 박정희 전 대통령의 기...
# 21     노 전 대통령은 1932년 12월4일 경북 달성군 공산면 신용리(현 대구 동구 신...
# 25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 4      (서울=뉴스1) 이호승 기자 = 제13대 대통령을 지낸 노태우 전 대통령이 26일...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 47     [아시아경제 양낙규 군사전문기자]26일 별세한 노태우 전 대통령이 국립현충원에 안...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# 43     [이데일리 박지혜 기자] 대한민국 제13대 대통령을 지낸 노태우 전 대통령이 26...
# Name: content, dtype: object
# 16 / 50
# 16 번 뉴스와 유사한 내용을 가진 뉴스목록
#  20      [서울=뉴시스] 류현주 기자 = 프로포폴 불법 투약 혐의를 받는 이재용 삼성전자...
# 5      신종 코로나바이러스 감염증(코로나19) 확산에 대처하는 중국의 해법은 하나다. 지...
# 36      # 내년 4월 결혼식을 위해 웨딩홀을 예약하려던 서울 서초동의 김모(32)씨. ...
# 30     독립운동가 안중근 의사의 조카며느리 고(故) 박태정 여사가 생활고로 삼일장도 치르...
# 10    기사내용 요약 홍준표측, 당원 투표 중 ARS전화때 본인인증 절차 도입 요구 선관위...
# 46    기사내용 요약 검찰, 김만배 남욱 소환 조사 이어가 '박영수 딸 특혜" 질문에 김만...
# 32    기사내용 요약 국가장 장례기간 5일 이내…조기 게양 '내란죄 복역' 국립묘지 안장 ...
# 48    기사내용 요약 공수처의 손준성 전 정책관 구속영장 청구 관련  변협 "방어권 보장 ...
# 13     "가계부채 대책이 실행되기 전에 급매라도 잡아야 하나요?", "내년부터 시행이면 ...
# 8      올해 겨울은 예상치 못한 한파가 갑자기 찾아오는 등 큰 폭의 기온 변화가 예상된다...
# Name: content, dtype: object
# 17 / 50
# 17 번 뉴스와 유사한 내용을 가진 뉴스목록
#  7     비리 의혹 목사 비호 의혹 방배서 경찰, 관련 취재 온 기자에 물리력 행사…휴대전화...
# 12     (시카고=연합뉴스) 김현 통신원 = 미국에서 많은 의문을 남긴 채 실종됐던 전도유...
# 34     (천안=뉴스1) 이시우 기자 = 충남 천안의 한 아파트 지하 주차장 화재로 차량 ...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 43     [이데일리 박지혜 기자] 대한민국 제13대 대통령을 지낸 노태우 전 대통령이 26...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 28     초기에 발견하기 어렵기 때문에 '침묵의 살인자'라 불리는 췌장암에 걸리는 젊은 여...
# 33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 40     자리에 오래 앉아 있는 직장인, 수험생은 허리 근육에 피로가 쌓이기 쉽다. 허리에...
# Name: content, dtype: object
# 18 / 50
# 18 번 뉴스와 유사한 내용을 가진 뉴스목록
#  42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# 38     (서울=뉴스1) 김규빈 기자,음상준 기자,권영미 기자,이형진 기자,강승지 기자 =...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# 7     비리 의혹 목사 비호 의혹 방배서 경찰, 관련 취재 온 기자에 물리력 행사…휴대전화...
# 43     [이데일리 박지혜 기자] 대한민국 제13대 대통령을 지낸 노태우 전 대통령이 26...
# 40     자리에 오래 앉아 있는 직장인, 수험생은 허리 근육에 피로가 쌓이기 쉽다. 허리에...
# 32    기사내용 요약 국가장 장례기간 5일 이내…조기 게양 '내란죄 복역' 국립묘지 안장 ...
# 33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# Name: content, dtype: object
# 19 / 50
# 19 번 뉴스와 유사한 내용을 가진 뉴스목록
#  22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# 15     (서울=연합뉴스) 이준서 기자 = 대한민국 제13대 대통령을 지낸 노태우 전 대통...
# 27     김용판 의원은 이날 '돈다발' 사진과 관련해 "민주당은 돈다발 사진이 박철민 페이...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# Name: content, dtype: object
# 20 / 50
# 20 번 뉴스와 유사한 내용을 가진 뉴스목록
#  46    기사내용 요약 검찰, 김만배 남욱 소환 조사 이어가 '박영수 딸 특혜" 질문에 김만...
# 37     (서울=뉴스1) 한유주 기자,최현만 기자 = 고발사주 의혹의 핵심인물이자 텔레그램...
# 16    기사내용 요약 농식품부, 단계적 일상회복 맞춰 외식 쿠폰 확대 잔여 예산 180억 ...
# 32    기사내용 요약 국가장 장례기간 5일 이내…조기 게양 '내란죄 복역' 국립묘지 안장 ...
# 34     (천안=뉴스1) 이시우 기자 = 충남 천안의 한 아파트 지하 주차장 화재로 차량 ...
# 48    기사내용 요약 공수처의 손준성 전 정책관 구속영장 청구 관련  변협 "방어권 보장 ...
# 10    기사내용 요약 홍준표측, 당원 투표 중 ARS전화때 본인인증 절차 도입 요구 선관위...
# 1            손 검사는 지난해 4월 대검찰청 수사정보정책관 재직 당시 국회의원 후보...
# 47     [아시아경제 양낙규 군사전문기자]26일 별세한 노태우 전 대통령이 국립현충원에 안...
# 25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# Name: content, dtype: object
# 21 / 50
# 21 번 뉴스와 유사한 내용을 가진 뉴스목록
#  15     (서울=연합뉴스) 이준서 기자 = 대한민국 제13대 대통령을 지낸 노태우 전 대통...
# 4      (서울=뉴스1) 이호승 기자 = 제13대 대통령을 지낸 노태우 전 대통령이 26일...
# 29     노태우 전 대통령이 26일 별세했다. 향년 89세. 이날은 박정희 전 대통령의 기...
# 25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 47     [아시아경제 양낙규 군사전문기자]26일 별세한 노태우 전 대통령이 국립현충원에 안...
# 43     [이데일리 박지혜 기자] 대한민국 제13대 대통령을 지낸 노태우 전 대통령이 26...
# 19     대구에서도 윤석열 국민의힘 대선주자의 전두환 옹호 발언과 개사과 사진을 비판하는 ...
# Name: content, dtype: object
# 22 / 50
# 22 번 뉴스와 유사한 내용을 가진 뉴스목록
#  33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 41     국민의힘 대선 후보를 결정하기 위한 본경선 여론조사 문항이 결정됐다. '가상 양자...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 14     - 김종인과 만남 거절당했다는 것은 거짓말 - 김종인, 경선에서 만날 생각 없어 ...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# 19     대구에서도 윤석열 국민의힘 대선주자의 전두환 옹호 발언과 개사과 사진을 비판하는 ...
# Name: content, dtype: object
# 23 / 50
# 23 번 뉴스와 유사한 내용을 가진 뉴스목록
#  22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 15     (서울=연합뉴스) 이준서 기자 = 대한민국 제13대 대통령을 지낸 노태우 전 대통...
# 29     노태우 전 대통령이 26일 별세했다. 향년 89세. 이날은 박정희 전 대통령의 기...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# 33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# Name: content, dtype: object
# 24 / 50
# 24 번 뉴스와 유사한 내용을 가진 뉴스목록
#  25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 29     노태우 전 대통령이 26일 별세했다. 향년 89세. 이날은 박정희 전 대통령의 기...
# 4      (서울=뉴스1) 이호승 기자 = 제13대 대통령을 지낸 노태우 전 대통령이 26일...
# 15     (서울=연합뉴스) 이준서 기자 = 대한민국 제13대 대통령을 지낸 노태우 전 대통...
# 21     노 전 대통령은 1932년 12월4일 경북 달성군 공산면 신용리(현 대구 동구 신...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 47     [아시아경제 양낙규 군사전문기자]26일 별세한 노태우 전 대통령이 국립현충원에 안...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 43     [이데일리 박지혜 기자] 대한민국 제13대 대통령을 지낸 노태우 전 대통령이 26...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# Name: content, dtype: object
# 25 / 50
# 25 번 뉴스와 유사한 내용을 가진 뉴스목록
#  29     노태우 전 대통령이 26일 별세했다. 향년 89세. 이날은 박정희 전 대통령의 기...
# 15     (서울=연합뉴스) 이준서 기자 = 대한민국 제13대 대통령을 지낸 노태우 전 대통...
# 4      (서울=뉴스1) 이호승 기자 = 제13대 대통령을 지낸 노태우 전 대통령이 26일...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 47     [아시아경제 양낙규 군사전문기자]26일 별세한 노태우 전 대통령이 국립현충원에 안...
# 21     노 전 대통령은 1932년 12월4일 경북 달성군 공산면 신용리(현 대구 동구 신...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 43     [이데일리 박지혜 기자] 대한민국 제13대 대통령을 지낸 노태우 전 대통령이 26...
# Name: content, dtype: object
# 26 / 50
# 26 번 뉴스와 유사한 내용을 가진 뉴스목록
#  23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 29     노태우 전 대통령이 26일 별세했다. 향년 89세. 이날은 박정희 전 대통령의 기...
# 15     (서울=연합뉴스) 이준서 기자 = 대한민국 제13대 대통령을 지낸 노태우 전 대통...
# 25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# 19     대구에서도 윤석열 국민의힘 대선주자의 전두환 옹호 발언과 개사과 사진을 비판하는 ...
# Name: content, dtype: object
# 27 / 50
# 27 번 뉴스와 유사한 내용을 가진 뉴스목록
#  49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 1            손 검사는 지난해 4월 대검찰청 수사정보정책관 재직 당시 국회의원 후보...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# 19     대구에서도 윤석열 국민의힘 대선주자의 전두환 옹호 발언과 개사과 사진을 비판하는 ...
# 41     국민의힘 대선 후보를 결정하기 위한 본경선 여론조사 문항이 결정됐다. '가상 양자...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# Name: content, dtype: object
# 28 / 50
# 28 번 뉴스와 유사한 내용을 가진 뉴스목록
#  6      지난 21일 누리호가 우주로 향할 준비를 하고 있을 무렵. 발사대에서 20km 떨...
# 38     (서울=뉴스1) 김규빈 기자,음상준 기자,권영미 기자,이형진 기자,강승지 기자 =...
# 12     (시카고=연합뉴스) 김현 통신원 = 미국에서 많은 의문을 남긴 채 실종됐던 전도유...
# 31     [아시아경제 이춘희 기자] 현재 만 59세인 국민연금의 의무가입 상한 연령을 64...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 0     나루히토(德仁) 일왕의 조카인 마코(眞子·30) 공주가 26일 약혼자 고무로 게이(...
# 17     [이데일리 송혜수 기자] 현직 20대 여성 순경이 만취 상태로 오토바이를 몰고 상...
# 8      올해 겨울은 예상치 못한 한파가 갑자기 찾아오는 등 큰 폭의 기온 변화가 예상된다...
# 1            손 검사는 지난해 4월 대검찰청 수사정보정책관 재직 당시 국회의원 후보...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# Name: content, dtype: object
# 29 / 50
# 29 번 뉴스와 유사한 내용을 가진 뉴스목록
#  25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 15     (서울=연합뉴스) 이준서 기자 = 대한민국 제13대 대통령을 지낸 노태우 전 대통...
# 4      (서울=뉴스1) 이호승 기자 = 제13대 대통령을 지낸 노태우 전 대통령이 26일...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 47     [아시아경제 양낙규 군사전문기자]26일 별세한 노태우 전 대통령이 국립현충원에 안...
# 21     노 전 대통령은 1932년 12월4일 경북 달성군 공산면 신용리(현 대구 동구 신...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 43     [이데일리 박지혜 기자] 대한민국 제13대 대통령을 지낸 노태우 전 대통령이 26...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# Name: content, dtype: object
# 30 / 50
# 30 번 뉴스와 유사한 내용을 가진 뉴스목록
#  39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# 32    기사내용 요약 국가장 장례기간 5일 이내…조기 게양 '내란죄 복역' 국립묘지 안장 ...
# 4      (서울=뉴스1) 이호승 기자 = 제13대 대통령을 지낸 노태우 전 대통령이 26일...
# 2      지난 6월 한국의 영부인 김정숙 여사는 영국 콘월 미낙극장(Minack Theat...
# 16    기사내용 요약 농식품부, 단계적 일상회복 맞춰 외식 쿠폰 확대 잔여 예산 180억 ...
# 47     [아시아경제 양낙규 군사전문기자]26일 별세한 노태우 전 대통령이 국립현충원에 안...
# 15     (서울=연합뉴스) 이준서 기자 = 대한민국 제13대 대통령을 지낸 노태우 전 대통...
# 29     노태우 전 대통령이 26일 별세했다. 향년 89세. 이날은 박정희 전 대통령의 기...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# 25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# Name: content, dtype: object
# 31 / 50
# 31 번 뉴스와 유사한 내용을 가진 뉴스목록
#  11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 28     초기에 발견하기 어렵기 때문에 '침묵의 살인자'라 불리는 췌장암에 걸리는 젊은 여...
# 33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 38     (서울=뉴스1) 김규빈 기자,음상준 기자,권영미 기자,이형진 기자,강승지 기자 =...
# 13     "가계부채 대책이 실행되기 전에 급매라도 잡아야 하나요?", "내년부터 시행이면 ...
# 3      (서울=뉴스1) 이형진 기자 = 방역당국이 오는 28일 신종 코로나바이러스 감염증...
# 30     독립운동가 안중근 의사의 조카며느리 고(故) 박태정 여사가 생활고로 삼일장도 치르...
# 16    기사내용 요약 농식품부, 단계적 일상회복 맞춰 외식 쿠폰 확대 잔여 예산 180억 ...
# 22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 47     [아시아경제 양낙규 군사전문기자]26일 별세한 노태우 전 대통령이 국립현충원에 안...
# Name: content, dtype: object
# 32 / 50
# 32 번 뉴스와 유사한 내용을 가진 뉴스목록
#  47     [아시아경제 양낙규 군사전문기자]26일 별세한 노태우 전 대통령이 국립현충원에 안...
# 25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 29     노태우 전 대통령이 26일 별세했다. 향년 89세. 이날은 박정희 전 대통령의 기...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 15     (서울=연합뉴스) 이준서 기자 = 대한민국 제13대 대통령을 지낸 노태우 전 대통...
# 4      (서울=뉴스1) 이호승 기자 = 제13대 대통령을 지낸 노태우 전 대통령이 26일...
# 21     노 전 대통령은 1932년 12월4일 경북 달성군 공산면 신용리(현 대구 동구 신...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# Name: content, dtype: object
# 33 / 50
# 33 번 뉴스와 유사한 내용을 가진 뉴스목록
#  22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 41     국민의힘 대선 후보를 결정하기 위한 본경선 여론조사 문항이 결정됐다. '가상 양자...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 14     - 김종인과 만남 거절당했다는 것은 거짓말 - 김종인, 경선에서 만날 생각 없어 ...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 19     대구에서도 윤석열 국민의힘 대선주자의 전두환 옹호 발언과 개사과 사진을 비판하는 ...
# Name: content, dtype: object
# 34 / 50
# 34 번 뉴스와 유사한 내용을 가진 뉴스목록
#  7     비리 의혹 목사 비호 의혹 방배서 경찰, 관련 취재 온 기자에 물리력 행사…휴대전화...
# 17     [이데일리 송혜수 기자] 현직 20대 여성 순경이 만취 상태로 오토바이를 몰고 상...
# 8      올해 겨울은 예상치 못한 한파가 갑자기 찾아오는 등 큰 폭의 기온 변화가 예상된다...
# 20      [서울=뉴시스] 류현주 기자 = 프로포폴 불법 투약 혐의를 받는 이재용 삼성전자...
# 46    기사내용 요약 검찰, 김만배 남욱 소환 조사 이어가 '박영수 딸 특혜" 질문에 김만...
# 37     (서울=뉴스1) 한유주 기자,최현만 기자 = 고발사주 의혹의 핵심인물이자 텔레그램...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 12     (시카고=연합뉴스) 김현 통신원 = 미국에서 많은 의문을 남긴 채 실종됐던 전도유...
# 22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# Name: content, dtype: object
# 35 / 50
# 35 번 뉴스와 유사한 내용을 가진 뉴스목록
#  22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# 14     - 김종인과 만남 거절당했다는 것은 거짓말 - 김종인, 경선에서 만날 생각 없어 ...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 37     (서울=뉴스1) 한유주 기자,최현만 기자 = 고발사주 의혹의 핵심인물이자 텔레그램...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# Name: content, dtype: object
# 36 / 50
# 36 번 뉴스와 유사한 내용을 가진 뉴스목록
#  3      (서울=뉴스1) 이형진 기자 = 방역당국이 오는 28일 신종 코로나바이러스 감염증...
# 5      신종 코로나바이러스 감염증(코로나19) 확산에 대처하는 중국의 해법은 하나다. 지...
# 16    기사내용 요약 농식품부, 단계적 일상회복 맞춰 외식 쿠폰 확대 잔여 예산 180억 ...
# 38     (서울=뉴스1) 김규빈 기자,음상준 기자,권영미 기자,이형진 기자,강승지 기자 =...
# 13     "가계부채 대책이 실행되기 전에 급매라도 잡아야 하나요?", "내년부터 시행이면 ...
# 6      지난 21일 누리호가 우주로 향할 준비를 하고 있을 무렵. 발사대에서 20km 떨...
# 43     [이데일리 박지혜 기자] 대한민국 제13대 대통령을 지낸 노태우 전 대통령이 26...
# 0     나루히토(德仁) 일왕의 조카인 마코(眞子·30) 공주가 26일 약혼자 고무로 게이(...
# 37     (서울=뉴스1) 한유주 기자,최현만 기자 = 고발사주 의혹의 핵심인물이자 텔레그램...
# 2      지난 6월 한국의 영부인 김정숙 여사는 영국 콘월 미낙극장(Minack Theat...
# Name: content, dtype: object
# 37 / 50
# 37 번 뉴스와 유사한 내용을 가진 뉴스목록
#  48    기사내용 요약 공수처의 손준성 전 정책관 구속영장 청구 관련  변협 "방어권 보장 ...
# 1            손 검사는 지난해 4월 대검찰청 수사정보정책관 재직 당시 국회의원 후보...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 46    기사내용 요약 검찰, 김만배 남욱 소환 조사 이어가 '박영수 딸 특혜" 질문에 김만...
# 20      [서울=뉴시스] 류현주 기자 = 프로포폴 불법 투약 혐의를 받는 이재용 삼성전자...
# 7     비리 의혹 목사 비호 의혹 방배서 경찰, 관련 취재 온 기자에 물리력 행사…휴대전화...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# Name: content, dtype: object
# 38 / 50
# 38 번 뉴스와 유사한 내용을 가진 뉴스목록
#  9     왕이 중국 외교담당 국무위원 겸 외교부장이 일본을 향해 “역사 인식과 대만 등은 중...
# 5      신종 코로나바이러스 감염증(코로나19) 확산에 대처하는 중국의 해법은 하나다. 지...
# 3      (서울=뉴스1) 이형진 기자 = 방역당국이 오는 28일 신종 코로나바이러스 감염증...
# 36      # 내년 4월 결혼식을 위해 웨딩홀을 예약하려던 서울 서초동의 김모(32)씨. ...
# 28     초기에 발견하기 어렵기 때문에 '침묵의 살인자'라 불리는 췌장암에 걸리는 젊은 여...
# 22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 0     나루히토(德仁) 일왕의 조카인 마코(眞子·30) 공주가 26일 약혼자 고무로 게이(...
# 31     [아시아경제 이춘희 기자] 현재 만 59세인 국민연금의 의무가입 상한 연령을 64...
# 7     비리 의혹 목사 비호 의혹 방배서 경찰, 관련 취재 온 기자에 물리력 행사…휴대전화...
# 18    2021년 9월의 제주 여행기입니다. <기자말> [노시경 기자]  안덕계곡 입구의 ...
# Name: content, dtype: object
# 39 / 50
# 39 번 뉴스와 유사한 내용을 가진 뉴스목록
#  15     (서울=연합뉴스) 이준서 기자 = 대한민국 제13대 대통령을 지낸 노태우 전 대통...
# 25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 29     노태우 전 대통령이 26일 별세했다. 향년 89세. 이날은 박정희 전 대통령의 기...
# 43     [이데일리 박지혜 기자] 대한민국 제13대 대통령을 지낸 노태우 전 대통령이 26...
# 4      (서울=뉴스1) 이호승 기자 = 제13대 대통령을 지낸 노태우 전 대통령이 26일...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 47     [아시아경제 양낙규 군사전문기자]26일 별세한 노태우 전 대통령이 국립현충원에 안...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 21     노 전 대통령은 1932년 12월4일 경북 달성군 공산면 신용리(현 대구 동구 신...
# 19     대구에서도 윤석열 국민의힘 대선주자의 전두환 옹호 발언과 개사과 사진을 비판하는 ...
# Name: content, dtype: object
# 40 / 50
# 40 번 뉴스와 유사한 내용을 가진 뉴스목록
#  17     [이데일리 송혜수 기자] 현직 20대 여성 순경이 만취 상태로 오토바이를 몰고 상...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# 8      올해 겨울은 예상치 못한 한파가 갑자기 찾아오는 등 큰 폭의 기온 변화가 예상된다...
# 18    2021년 9월의 제주 여행기입니다. <기자말> [노시경 기자]  안덕계곡 입구의 ...
# 28     초기에 발견하기 어렵기 때문에 '침묵의 살인자'라 불리는 췌장암에 걸리는 젊은 여...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 19     대구에서도 윤석열 국민의힘 대선주자의 전두환 옹호 발언과 개사과 사진을 비판하는 ...
# 6      지난 21일 누리호가 우주로 향할 준비를 하고 있을 무렵. 발사대에서 20km 떨...
# 36      # 내년 4월 결혼식을 위해 웨딩홀을 예약하려던 서울 서초동의 김모(32)씨. ...
# Name: content, dtype: object
# 41 / 50
# 41 번 뉴스와 유사한 내용을 가진 뉴스목록
#  33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 10    기사내용 요약 홍준표측, 당원 투표 중 ARS전화때 본인인증 절차 도입 요구 선관위...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 14     - 김종인과 만남 거절당했다는 것은 거짓말 - 김종인, 경선에서 만날 생각 없어 ...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 27     김용판 의원은 이날 '돈다발' 사진과 관련해 "민주당은 돈다발 사진이 박철민 페이...
# Name: content, dtype: object
# 42 / 50
# 42 번 뉴스와 유사한 내용을 가진 뉴스목록
#  35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 19     대구에서도 윤석열 국민의힘 대선주자의 전두환 옹호 발언과 개사과 사진을 비판하는 ...
# 25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 29     노태우 전 대통령이 26일 별세했다. 향년 89세. 이날은 박정희 전 대통령의 기...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# Name: content, dtype: object
# 43 / 50
# 43 번 뉴스와 유사한 내용을 가진 뉴스목록
#  25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 29     노태우 전 대통령이 26일 별세했다. 향년 89세. 이날은 박정희 전 대통령의 기...
# 15     (서울=연합뉴스) 이준서 기자 = 대한민국 제13대 대통령을 지낸 노태우 전 대통...
# 4      (서울=뉴스1) 이호승 기자 = 제13대 대통령을 지낸 노태우 전 대통령이 26일...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 21     노 전 대통령은 1932년 12월4일 경북 달성군 공산면 신용리(현 대구 동구 신...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 47     [아시아경제 양낙규 군사전문기자]26일 별세한 노태우 전 대통령이 국립현충원에 안...
# Name: content, dtype: object
# 44 / 50
# 44 번 뉴스와 유사한 내용을 가진 뉴스목록
#  22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 41     국민의힘 대선 후보를 결정하기 위한 본경선 여론조사 문항이 결정됐다. '가상 양자...
# 14     - 김종인과 만남 거절당했다는 것은 거짓말 - 김종인, 경선에서 만날 생각 없어 ...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# Name: content, dtype: object
# 45 / 50
# 45 번 뉴스와 유사한 내용을 가진 뉴스목록
#  12     (시카고=연합뉴스) 김현 통신원 = 미국에서 많은 의문을 남긴 채 실종됐던 전도유...
# 8      올해 겨울은 예상치 못한 한파가 갑자기 찾아오는 등 큰 폭의 기온 변화가 예상된다...
# 43     [이데일리 박지혜 기자] 대한민국 제13대 대통령을 지낸 노태우 전 대통령이 26...
# 34     (천안=뉴스1) 이시우 기자 = 충남 천안의 한 아파트 지하 주차장 화재로 차량 ...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 38     (서울=뉴스1) 김규빈 기자,음상준 기자,권영미 기자,이형진 기자,강승지 기자 =...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 13     "가계부채 대책이 실행되기 전에 급매라도 잡아야 하나요?", "내년부터 시행이면 ...
# 42    [곽우신 기자]  윤석열 후보는 박정희 전 대통령 사망 42주기를 맞아 26일 오후...
# 32    기사내용 요약 국가장 장례기간 5일 이내…조기 게양 '내란죄 복역' 국립묘지 안장 ...
# Name: content, dtype: object
# 46 / 50
# 46 번 뉴스와 유사한 내용을 가진 뉴스목록
#  48    기사내용 요약 공수처의 손준성 전 정책관 구속영장 청구 관련  변협 "방어권 보장 ...
# 20      [서울=뉴시스] 류현주 기자 = 프로포폴 불법 투약 혐의를 받는 이재용 삼성전자...
# 41     국민의힘 대선 후보를 결정하기 위한 본경선 여론조사 문항이 결정됐다. '가상 양자...
# 37     (서울=뉴스1) 한유주 기자,최현만 기자 = 고발사주 의혹의 핵심인물이자 텔레그램...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 7     비리 의혹 목사 비호 의혹 방배서 경찰, 관련 취재 온 기자에 물리력 행사…휴대전화...
# 34     (천안=뉴스1) 이시우 기자 = 충남 천안의 한 아파트 지하 주차장 화재로 차량 ...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 10    기사내용 요약 홍준표측, 당원 투표 중 ARS전화때 본인인증 절차 도입 요구 선관위...
# Name: content, dtype: object
# 47 / 50
# 47 번 뉴스와 유사한 내용을 가진 뉴스목록
#  32    기사내용 요약 국가장 장례기간 5일 이내…조기 게양 '내란죄 복역' 국립묘지 안장 ...
# 25     현대사에 빛과 그림자를 동시에 남긴 노태우 전 대통령이 26일 향년 89세로 눈을...
# 29     노태우 전 대통령이 26일 별세했다. 향년 89세. 이날은 박정희 전 대통령의 기...
# 15     (서울=연합뉴스) 이준서 기자 = 대한민국 제13대 대통령을 지낸 노태우 전 대통...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 4      (서울=뉴스1) 이호승 기자 = 제13대 대통령을 지낸 노태우 전 대통령이 26일...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 21     노 전 대통령은 1932년 12월4일 경북 달성군 공산면 신용리(현 대구 동구 신...
# 39     (서울=뉴스1) 김일창 기자 = 노태우 전 대통령이 26일 지병 악화로 서울 종로...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# Name: content, dtype: object
# 48 / 50
# 48 번 뉴스와 유사한 내용을 가진 뉴스목록
#  37     (서울=뉴스1) 한유주 기자,최현만 기자 = 고발사주 의혹의 핵심인물이자 텔레그램...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 46    기사내용 요약 검찰, 김만배 남욱 소환 조사 이어가 '박영수 딸 특혜" 질문에 김만...
# 1            손 검사는 지난해 4월 대검찰청 수사정보정책관 재직 당시 국회의원 후보...
# 7     비리 의혹 목사 비호 의혹 방배서 경찰, 관련 취재 온 기자에 물리력 행사…휴대전화...
# 49     (서울=뉴스1) 허고운 기자,이밝음 기자 = 26일 국회 행정안전위원회 종합감사에...
# 10    기사내용 요약 홍준표측, 당원 투표 중 ARS전화때 본인인증 절차 도입 요구 선관위...
# 20      [서울=뉴시스] 류현주 기자 = 프로포폴 불법 투약 혐의를 받는 이재용 삼성전자...
# 24      1970년대 중반의 일이다. 당시 공수여단장이었던 노태우 전 대통령은 난생 처음...
# 32    기사내용 요약 국가장 장례기간 5일 이내…조기 게양 '내란죄 복역' 국립묘지 안장 ...
# Name: content, dtype: object
# 49 / 50
# 49 번 뉴스와 유사한 내용을 가진 뉴스목록
#  33     윤석열 전 검찰총장의 이재명 더불어민주당 대선후보와 양자대결 경쟁력이 국민의힘 대...
# 27     김용판 의원은 이날 '돈다발' 사진과 관련해 "민주당은 돈다발 사진이 박철민 페이...
# 11     [아시아경제 박준이 기자] 이재명 더불어민주당 대선 후보와 홍준표 국민의힘 의원 ...
# 35     (서울=뉴스1) 이훈철 기자,김민성 기자 = 윤석열 국민의힘 대선 경선 후보가 2...
# 26    (서울=연합뉴스) 조민정 김수진 기자 = 더불어민주당 이재명 대선후보는 26일 청와...
# 44     이인제 전 국회의원이 더불어민주당 대선 후보로 이재명 경기도지사가 선출된 것과 관...
# 41     국민의힘 대선 후보를 결정하기 위한 본경선 여론조사 문항이 결정됐다. '가상 양자...
# 23    이재명 더불어민주당 대선 후보가 26일 문재인 대통령에게 지난 대선 당내 경선과 관...
# 14     - 김종인과 만남 거절당했다는 것은 거짓말 - 김종인, 경선에서 만날 생각 없어 ...
# 22     (서울=뉴스1) 최은지 기자 = 홍준표 국민의힘 대선 경선 후보가 이재명 더불어민...
# Name: content, dtype: object

# %% [markdown]
# 정리
#
# 1.데이터를 크롤링한다.
#
# 2.명사만 따로 추출해서 저장한다.
#
# 3.Tf-idf를 이용해서 문서유사도를 구한다.(핵심 단어만 찾아낸다.)
#
# 4.구한 값을 이용해서 코사인유사도로 비슷한 문서를 찾는다.

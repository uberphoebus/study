# %%
# 9to6 결석 금지, 잠수 금지, 사유 보고
# 예습하지 말 것; 혼선이 옴
# 복습할 것; 당일 소화, 1주에 대학수업 13주 분량, 한 학기 한 과목 종료, 한달이 한 학기
# 가능하면 github에 정리할 것
# 개발자 포트폴리오에 git은 필수
# 수업 중 질문은 바로바로 할 것, 5시반 이후에 자율학습과 질문
# 낙오자 없는 느린 수업이지만 잘 따라 올 것
# 베이스 이후에는 빠르게 나갈 것
# 이론 후 반드시 실습
# 챕터마다 텀 프로젝트
# 자더라도 캠을 켜고 잘 것
# 효율적으로 시간 활용 중점
# 파이썬 위에 머신러닝, 딥러닝.
# 기본은 파이썬과 데이터와 데이터프레임; 자유자제로 할 수 있어야 함
# 문법이 해결 안되면 막히고 재미가 없음
# 기초문법이 탄탄할 때까지 계속 활용

# mariadb 핸들링, sql dml 문법
# 아나콘다 말고 다른 툴 이용
# 풀셋 구성이지만, 무겁고 호환성에 문제가 있음, 코드를 다른 데에서 적용 어려움
# 풀셋보다 수작업으로 시작
# 주피터 랩, 코랩 등 사용, 경량화

# 판다스 기초 매우매우 중요; 데이터 분석에 있어서 구구단 수준, 당연한 것, 못하는게 이상한 것
# 넘파이와 판다스는 100% 호환, 축약은 판다스, 넘파이는 디테일
# 둘다 많이 사용
# 10min 만 알아도 50% 이상 안 것

# 분석되는 결과는 반드시 시각화로 보여 줄 것
# mat, sns만 알아도 충분함

# 데이터 베이스에 넣고 빼는 것 ; 정형 데이터
# 비정형데이터; 유튜브, 네이버 등
# xml 등은 반정형, 준정형 데이터

# eda 전사적 데이터 작업 시각화
# 타이타닉 데이터셋; 캐글의 출발점이 되었던 데이터 셋, 시초 공모전

# 남의 코드를 이해해서 복붙해서 쓰는 수준만 돼도 충분하다
# 오픈API, 구글링 활용, 긁어서 돌리는 것도 기술, 가독도 기술
# 가독을 하다보면 익히게 됨

# 직접적 모델링/핸들링은 가능성은 제로, 아무도 안시켜줌
# 5개월 가지고 남의 배는 가를 수 있다고 생각하면 안됨
# 최소 2-3년

# 작은 회사라도 어딜 가서도 배움. 다시 학원 가는일은 없도록
# 어디라도 가서 3, 6개월로 현장 갈 것.
# 사회에서 현장에서 부딪혀 보면 말투와 언어가 다름
# 3개월이면 수강생과는 다름

# mat, sb, np, pd는 하루도 안쓰는 날이 없을 것
# 문맥을 읽을수 있으면 됨

# sql mysql oracle 99.9% 우리나라 사용. 우리나라 db에서 oracle 모르면 db 사용 불가능
# 마지막 버전을 업그레이드 하여 mariadb == mysql
# 작은 규모에서 마리아 사용, 대규모는 마리아는 터짐
# 동시접속자 15명까지는 사용.
# ANSI SQL
# ANSI.org 국제 표준 중 db 표준. 승인 규격 존재. select insert update
# 오라클 기능이 100이면 마리아는 10~15 정도
# 오라클 db 사용하고 세팅할 것
# 분석할 때 오라클만 사용하지 않음
# RDB; 빅데이터는 이 수준으로 할 수 없는 양
# 오라클 위로 사용하는 툴;
# NoSQL은 DB. 빅데이터의 DB. 분산형 DB. 몽고, 스파크, 하둡, 하이브 등.
# 현업에서는 둘다 사용하게 될 것.
# 다만 환경이 구축이 안되기 때문에 RDB위주로 연습하게 될 것

# 비전공과는 무관
# 기사자격증만 있다면 전공 무관. kosa 경력증명서.
# 기사 or 컴공; 같은 효과
# 2-3년 차 이내에 따는 자격증

# https://url.kr/h6gif3
# https://drive.google.com/drive/folders/1e1BcmstIH16T2bdh8PxswAoGwlqUYlN4?usp=sharing

# 파이참 위주로 사용. IDE. 통합개발환경. 디버깅, 깃허브 연결, 싱크, 버전관리 등
# 자동완성 기능과 코드 컴파일, 디버깅 등

# sql developer. 하이디와 비슷한 툴. 오라클 전용. 4.2 설치 권장
# 오라클 버전 두 가지. express edition EE
# 윈도우 데스크탑에 상업용 오라클 버전 설치하지 말것. 문제 발생.
# 원격용 팀뷰어. 실행만 해도 됨

# 자바 환경 베이스. 자바 운영 개발 환경

# db 브라우저. sql 라이트. 초경량 db.

# cmd javr -version 에서 기존것이 나오면 사용 없으면 설치
# 환경변수 편집. 어디에 설치되었는지 감지.

# 설치순서; jdk, oracle, python 3.8 or 3.7, 파이참
# 압축푸는 바이너리 방식, exe 인스톨러 방식
# 인스톨러ㅓ는 제어판에 등록됨.

# 오라클 접속 / 테이블스페이스 / 유저 / 테이블
# crud; select insert 등. create read update delete.
# db 어디까지 다루냐고 질문받으면 rdb 오라클 사용하여 sql crud 한다고 대답
# oracle; select insert update delete
# pd; pd에서 crud 작업

# r과 통계. 파이썬 문법이 들어가지 않은 채로 r문법이 들어가면 혼선.
# 관공서는 r 사용. 관공서 제외 법인 업체는 모두 파이썬 사용
# 파이썬은 언어, r은 통계 패키지. 통계기능이 무궁무진하고 쉬움
# 기초통계 2주하고 머신러닝, 딥러닝하면 연결이 안됨.
# 머신/딥러닝 중간중간에 통계를 연결해서 배움. 같은 개념인데 용어가 다름.

# 자바는 두번 설치; jdk, jre 둘다 설치 되어 있는지 확인

# 오라클 비밀번호 0000
# 포트번호 1521. 중복되면 충돌남. 하나여야됨
# 접속 conn cmd 활용가능. GUI 세 방법. GUI 툴.
# cmd; sqlplus system/0000
# select * from tab 전부 조회
# 유저를 새로 만듦. 깨끗한 폴더 생성.
# create user ai identified by "0000"; 별도 공간 생성
# DBA db관리 admin
# grant dba to ai; exit
# sqlplus ai/0000 접속
# select * from tab; 하여 확인

# sqldev 설치 후, 자바 경로 잡아주기
# 녹색십자가; 수업용디비 ai 0000; ai 대소문자 구분
# sid 는 orcl로 되어 있음. 상업용이라 이해.
# xe는 c드라이브 하나와 같음
# 테스트 누르면 상태;성공

# create user ai identified by "0000";
# grant dba to ai;

# 파이썬 3.8.8
# 비트 영향은 크게 받지 않음. 금융데이터, 보안, 인증서를 받으려면 32bit
# 케라스 텐서플로는 무조건 64비트.
# 둘다 쓰면 둘다 설치가 됨.
# 기본 패키지만 사용할 수 있음.
# 임베디드 방식; c++, 자바, c를 섞어놓은 언어. 타입 지정을 안해도 되지만, 나름대로 갖추고 있음. 명시하지 않을 뿐 내부적으로는 있음. 타입이 사슬을 타고 가다보면 에러 찾기가 까다로움.
# **kwarg 여러 값을 받아서 문제가 되기도 함.
# 1. 복잡한 연산, def의 연쇄는 삼가함
# 2. 간단한 인터프리터가 아닐 경우, 코드가 길어질 경우 ide 이용
# 머신/딥러닝에서는 df 입력하면 데이터가 너무 크기 때문에 큰일남
# 대량 연산은 ide 이용. 주피터 자제.

# 기계를 학습시키는 것 training. 짧게는 5분, 길면 3~4일. 프로젝트에 따라 1주. 수용할 수 없을 양의 데이터양이면 코랩 사용할 수도. 무료 계정 사용할 수도 있음. 구글 코랩.

# 임베디드 방식은 설치패키지를 미리 내려놓고 끼워맞추면서 실행하는 방식. 파이썬은 c 기원. 커널 제어가 가능. 웹은 자바. 파이썬은 커널도 웹도 됨.
# 임베디드는 칩셋에 적용하는 것. c, c++, 파이썬
# 모바일 프로그램 빼고 다됨.
# 우리는 인스톨러 사용할 것.

# 파이썬 디렉토리 변경할 것; add path, c의 AI에

# 프롬프트에 (base)가 붙는 이유
# base는 바꿀수 있음 (venv)로 바꿀 것.
# 콘다, 파이썬 같이 쓸거라 총 3개
#

# %% [markdown]
# ## selenium
#
# 웹사이트가 동적으로 움직일 때 이용; 스크롤 할 때마다 데이터 송신하는 페이지 등
#
# doc, DOM 객체; html이 DOM으로 구성.

# %%
# 라이브러리 불러오기, 드라이버 실행
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys

# driver = Chrome('C:\jhpark\sync\python\chromedriver')

# %%
# url = 'https://www.w3schools.com/python/python_reference.asp'
# driver.get(url)
# assert 'NAVER' in driver.title # 작동 확인

# namer, id 등으로 불러올 수 있음
# css, xpath 등 다른 element는 copy에서 확인 가능
# xpath; xml path lang 웹 표준 확장 기호

# elem = driver.find_element_by_name() # 커서 위치
# elem.send_keys(Kyes.RETURN) # 키보드 입력
# send_keys(Keys,ARROW_DOWN) # 방향키도 가능

# html = driver.page_source

# %%
# driver.forward(), .back()

# find_element_by_id
# find_element_by_name
# find_element_by_xpath
# find_element_by_link_text
# find_element_by_partial_link_text
# find_element_by_tag_name
# find_element_by_class_name
# find_element_by_css_selector


# from selenium.webdriver.common.by import By

# driver.find_element(By.XPATH, '//button[text()="Some text"]')
# driver.find_elements(By.XPATH, '//button')

# ID = "id"
# XPATH = "xpath"
# LINK_TEXT = "link text"
# PARTIAL_LINK_TEXT = "partial link text"
# NAME = "name"
# TAG_NAME = "tag name"
# CLASS_NAME = "class name"
# CSS_SELECTOR = "css selector"

# html 파일 구성
# <html>
#  <body>
#   <form id="loginForm">
#    <input name="username" type="text" />
#    <input name="password" type="password" />
#    <input name="continue" type="submit" value="Login" />
#   </form>
#  </body>
# </html>

# input은 대부분 form 태그로 구성

# %%
# 실습; 웹페이지 스크릿샷 저장

from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium import webdriver

# url = 'https://www.naver.com'
# # driver.get(url)

# elem = driver.find_element_by_name('query') # 커서 위치
# elem.send_keys('충무로역 맛집') # 키보드 입력

# elem.send_keys(Keys.RETURN) # 키보드 입력

# driver.save_screenshot('pythoss.jpg')

# %%
print(dir(Chrome)) # 명령어 불러오기
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_unwrap_value', '_web_element_cls', '_wrap_value', 'add_cookie', 'application_cache', 'back', 'close', 'create_options', 'create_web_element', 'current_url', 'current_window_handle', 'delete_all_cookies', 'delete_cookie', 'desired_capabilities', 'execute', 'execute_async_script', 'execute_cdp_cmd', 'execute_script', 'file_detector', 'file_detector_context', 'find_element', 'find_element_by_class_name', 'find_element_by_css_selector', 'find_element_by_id', 'find_element_by_link_text', 'find_element_by_name', 'find_element_by_partial_link_text', 'find_element_by_tag_name', 'find_element_by_xpath', 'find_elements', 'find_e
# ...

# %%
# selenium 페이지 이동, 메뉴 찾기

# url = 'https://www.python.org'
# driver.get(url)

# elem = driver.find_element_by_css_selector('#top > nav > ul li')
# elem.send_keys() # 키보드 입력

# elem.send_keys(Keys.RETURN)

# %%
from selenium import webdriver
import time

# browser = webdriver.Chrome('C:\jhpark\sync\python\chromedriver')
# browser.get('http:/python.org')

# menus = browser.find_elements_by_css_selector('#top > nav > ul li')

# pypi = None

# print('menus = ', menus)

# for m in menus:
#     if m.text == 'PyPI':
#         pypi = m
#     print(m.text)
    
# print('pypi = ', pypi)
# pypi.click()

# %% [markdown]
# ## 브라우저 없이 실행하기

# %%
# from selenium import webdriver

# options = webdriver.ChromeOptions()
# options.add_argument('headless')

# driver = webdriver.Chrome('C:\jhpark\sync\python\chromedriver', options=options)

# driver.get('http://python.org')

# res = driver.page_source

# print(len(res))

# %%
# # 실습; 유튜브 키워드 검색 수집
# # 1. 화면에서 키워드를 입력 받음 '파이썬 데이터분석'
# # 2. sel 활용 검색창에 입력 후 검색 실행
# # 3. page_source를 받아서 BeautifulSoup 적용; 태그 찾기
# # 4. 데이터 추출 후 DateFrame으로 만들기
# #    - 개별 영상 타입; 채널명, 영상제묙, 영상 url, 조회수, 영상 등록 날짜
# # channel, title, url, views, date
# #    - 재생 목록 타입; 채널명, 재생목록제목, 재생목록url
# # chnnel, listtitle, listurl
# # 5. 함수로 만들어 처리
# #    - 개별영상타입 함수; video_item()
# #    - 재생목록타입 함수; video_playlist()

# from selenium.webdriver import Chrome
# from selenium.webdriver.common.keys import Keys
# import time
# from bs4 import BeautifulSoup
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.support.ui import WebDriverWait
# import pandas as pd

# # 드라이버 실행
# url = 'https://www.youtube.com/'
# driver = Chrome('C:\jhpark\sync\python\chromedriver')
# driver.get(url)

# # 검색어 검색
# driver.implicitly_wait(2)
# elem = driver.find_element_by_name('search_query')
# driver.implicitly_wait(2)
# elem.send_keys('파이썬 데이터분석')
# button = driver.find_element_by_id('search-icon-legacy')
# button.click()
# driver.implicitly_wait(2)

# # 페이지 소스 조회
# driver.implicitly_wait(2)
# html = driver.page_source
# driver.implicitly_wait(2)
# soup = BeautifulSoup(html, 'html.parser')
# driver.implicitly_wait(2)


# # 개별 영상 타입
# # 태그 검색
# # t0 = soup.find('ytd-video-renderer', {'class':'style-scope ytd-item-section-renderer'})
# # t1 = t0.find('h3', {'class':'title-and-badge style-scope ytd-video-renderer'})
# # t2 = t0.find_all('span', {'class':'style-scope ytd-video-meta-block'})
# # # 데이터 조회
# # channel = t0.find('ytd-channel-name', {'id':'channel-name'}).find('a').text
# # title = t1.find('a').text.replace('\n', '')
# # url = 'https://www.youtube.com/' + t0.find('ytd-channel-name', {'id':'channel-name'}).find('a')['href']
# # views = t2[0].text
# # date = t2[1].text
# # # 데이터 리스트 구성
# # video = []
# # video.append([channel, title, views, date, url])


# # # 재생목록 타입
# # # 태그 검색
# # p0 = soup.find('div', {'class':'style-scope ytd-playlist-renderer'})
# # p1 = p0.find('span', {'id':'video-title'})
# # # 데이터 조회
# # channel_l = p0.find('div', {'id':'text-container'}).text.replace('\n', '')
# # title_l = p1.text.replace('\n', '').strip()
# # url_l = 'https://www.youtube.com/' + p0.find('yt-formatted-string', {'id':'view-more'}).find('a')['href']
# # # 데이터 리스트 구성
# # playlist = []
# # playlist.append([channel_l, title_l, url_l])

# # 함수 구성

# def video_item(soup):
#     """soup 페이지소스를 받아, 태그를 검색하여 데이터 조회한 후 리스트 구성"""
#     # 태그 검색
#     t0 = soup.find('div', {'class':'style-scope ytd-item-section-renderer'})
#     t1 = t0.find('h3', {'class':'title-and-badge style-scope ytd-video-renderer'})
#     t2 = t0.find_all('span', {'class':'style-scope ytd-video-meta-block'})
#     # 데이터 조회
#     channel = t0.find('ytd-channel-name', {'id':'channel-name'}).find('a').text
#     title = t1.find('a').text.replace('\n', '')
#     url = 'https://www.youtube.com/' + t0.find('ytd-channel-name', {'id':'channel-name'}).find('a')['href']
#     views = t2[0].text
#     date = t2[1].text.replace('전', '').replace('개월', '')
#     # 데이터 리스트 구성
#     video = []
#     video.append([channel, title, views, date, url])
#     return video

def video_playlist(soup):
    """soup 페이지소스를 받아, 태그를 검색하여 데이터 조회한 후 리스트 구성"""
    # 태그 검색
    p0 = soup.find('div', {'class':'style-scope ytd-playlist-renderer'})
    p1 = p0.find('span', {'id':'video-title'})
    # 데이터 조회
    channel_l = p0.find('div', {'id':'text-container'}).text.replace('\n', '')
    title_l = p1.text.replace('\n', '').strip()
    url_l = 'https://www.youtube.com/' + p0.find('yt-formatted-string', {'id':'view-more'}).find('a')['href']
    # 데이터 리스트 구성
    playlist = []
    playlist.append([channel_l, title_l, url_l])
    return playlist

# video = video_item(soup)
# playlist = video_playlist(soup)

# # df 구성
# video_df = pd.DataFrame(video, columns=['channel', 'title', 'views', 'date', 'url'])
# playlist_df = pd.DataFrame(playlist, columns=['channel_l', 'title_l', 'url_l'])

# print(video_df)
# playlist_df

# %% [markdown]
# ## api 공공데이터포털 코로나19
# Application Programming Interface
#
# 1. 공공데이터 포털 가입(data.go.kr)
#    - 로그인
#    - 필요 데이터 활용 신청; 동의합니다.
# 2. Open API 활용 가이드
# 3. 인증키 필요
# 4. End Point
# 5. URL 만들어서 -> 데이터 요청하기
#    - url = end_point + Operation + key + data_format
#    - url을 브라우저에서 실행해서 확인
#
# 언어마다 샘플도 있음
#
# 일반 인증키를 복사해둠
#
# 데이터를 검색하면 다 다른 데이터 형식을 업로드해서,
#
# '표준데이터셋' 형태로 정리함. 해당 형태로 정리해야 함
#
# http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19SidoInfStateJson?serviceKey=인증키(URL Encode) &pageNo=1&numOfRows=10&startCreateDt=20200410&endCreateDt=20200410
#
# 에서 인증키만 바꿔주면 됨
#
# operation 명 == 영문서비스명

# %%
my_key = 'uERvRwcxuakpKoIT7D%2FVwKIosqibQV%2BLsNcj6uKMdKBPiiy9tpNKFKg8P%2Bs0DqEuiz%2BrFgivpo4icWJzh27h5A%3D%3D'
t_key = '0C6iX2Ww%2BnB9GVY6k9Et5H9zqv%2FxjEsldVq1Wa9Co3lvcuaRi%2BI3gcoFoi3AckHg6B8AAf1cH0tKH4MXhYf57A%3D%3D'

# %%
end_point = 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19SidoInfStateJson?serviceKey='
params = '&pageNo=1&numOfRows=10&startCreateDt=20210801&endCreateDt=20210801'
data_format = '&type=xml'

url = end_point + t_key + params + data_format
print(url)
# Out:
# http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19SidoInfStateJson?serviceKey=0C6iX2Ww%2BnB9GVY6k9Et5H9zqv%2FxjEsldVq1Wa9Co3lvcuaRi%2BI3gcoFoi3AckHg6B8AAf1cH0tKH4MXhYf57A%3D%3D&pageNo=1&numOfRows=10&startCreateDt=20210801&endCreateDt=20210801&type=xml

# %%
# url 데이터 가져오기
import requests
res = requests.get(url)
# res

# %%
# xml데이터를 dict 구조로 변환
import xmltodict
result = xmltodict.parse(res.text)
# result

# %%
# dict구조를 json구조로 변환
import json
json = json.loads(json.dumps(result))
# json

# %%
# 데이터 구조 정제
json_dict = json['response']['body']['items']['item']
# json_dict

# %%
type(json_dict)
# json_dict
# Out:
# list

# %%
# 실습; 'createDt', 'deathCnt', 'defCnt', 'localOccCnt', 'overFlowCnt'
import pandas as pd
df = pd.DataFrame(json_dict)
# df[['createDt', 'deathCnt', 'defCnt', 'localOccCnt', 'overFlowCnt']]

# %%
df2 = pd.json_normalize(json_dict) # json데이터를 df구조로 변환
# df2

# %%
# 실습; 공공데이터 출입국 관광통계 서비스
# 1. end_point
# 2. my_key
# 3. params; YM=202101, NAT_CD=112, ED_CD=E
# 4. url 만들어서 브라우저 확인
# 5. df 구성

import requests
import xmltodict
import json
import pandas as pd

my_key = 'uERvRwcxuakpKoIT7D%2FVwKIosqibQV%2BLsNcj6uKMdKBPiiy9tpNKFKg8P%2Bs0DqEuiz%2BrFgivpo4icWJzh27h5A%3D%3D'
end_point = 'http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsServicee/getEdrcntTourismStatsList?serviceKey='
params = '&YM=201201&NAT_CD=112&ED_CD=D'
data_format = '&type=xml'

url = end_point + my_key + params + data_format

req = requests.get(url)
orderdict = xmltodict.parse(req.text)

tour_d = json.loads(json.dumps(orderdict))
tour_l = tour_d['response']['body']['items']['item']

tour_df = pd.DataFrame(tour_l)
tour_df
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# <ipython-input-32-b16cfc89995b> in <module>
#      19
#      20 req = requests.get(url)
# ---> 21 orderdict = xmltodict.parse(req.text)
#      22
#      23 tour_d = json.loads(json.dumps(orderdict))
#
# ~\anaconda3\lib\site-packages\xmltodict.py in parse(xml_input, encoding, expat, process_namespaces, namespace_separator, disable_entities, **kwargs)
#     325         parser.ParseFile(xml_input)
#     326     else:
# --> 327         parser.Parse(xml_input, True)
#     328     return handler.item
#     329
#
# ExpatError: syntax error: line 1, column 0

# %%
# 실습
# 1. 2019, 2020년 1~12월
# 2. 112(중국), 130(일본), 275(미국)
# 3. 통합하여 df구성

import requests
import xmltodict
import json
import pandas as pd

years = ['2019', '2020']
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
countries = ['112', '130', '275']
tour_l_total = []

def tour_func(countries, years, months):
    my_key = 'uERvRwcxuakpKoIT7D%2FVwKIosqibQV%2BLsNcj6uKMdKBPiiy9tpNKFKg8P%2Bs0DqEuiz%2BrFgivpo4icWJzh27h5A%3D%3D'
    end_point = 'http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getOvseaTuristStatsList?serviceKey='
    params = '&YM=' + years + months + '&NAT_CD=' + countries + '&ED_CD=D'
    data_format = '&type=xml'
    url = end_point + my_key + params + data_format
    
    req = requests.get(url)
    orderdict = xmltodict.parse(req.text)
    tour_d = json.loads(json.dumps(orderdict))
    tour_l = tour_d['response']['body']['items']['item']
    return tour_l

for i in countries:
    for j in years:
        for k in months:
            tour_l = tour_func(i, j, k)
            tour_l_total += tour_l
print(len(tour_l_total))
# Out:
# 720

# %%
tour_df = pd.DataFrame(tour_l_total)
tour_df
# Out:
#          age ageCd   num  port portCd rnum sex sexCd      ym
# 0    31 - 40    40  1178  제  주     CJ    1  여성     F  201901
# 1    21 - 30    30   980  제  주     CJ    2  남성     M  201901
# 2    11 - 20    20  1286  제  주     CJ    3  남성     M  201901
# 3    61 - 70    70   374  제  주     CJ    4  남성     M  201901
# 4     0 - 10    10   464  제  주     CJ    5  여성     F  201901
# ..       ...   ...   ...   ...    ...  ...  ..   ...     ...
# 715     71 -    80     0  제  주     CJ    6  여성     F  202012
# 716  21 - 30    30   149  제  주     CJ    7  남성     M  202012
# 717  11 - 20    20     1  제  주     CJ    8  여성     F  202012
# 718  31 - 40    40   227  제  주     CJ    9  남성     M  202012
# 719  51 - 60    60     1  제  주     CJ   10  여성     F  202012
#
# [720 rows x 9 columns]

# %%
# ( 실습2. 공공데이터 출입군 관광통계 서비스 )
# 나라 -> 112(중국), 130(일본), 275(미국)
# 년도 -> 2019, 2020
# 1월~12월
# DataFrame 만들기 (3 * 2 * 12 )
# ym(년월), natKorNm(국가), num(방문객수), edCD(구분)

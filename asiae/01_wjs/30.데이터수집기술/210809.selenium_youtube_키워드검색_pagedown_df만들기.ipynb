# %% [markdown]
# ### ( 1. 데이터 검색 후 검색결과 html 받기 )

# %%
from selenium import webdriver
import time

driver = webdriver.Chrome("c:/jswoo/chromedriver")

#search_word = input("검색어? ")
search_word = "파이썬 데이터분석"

url = "https://www.youtube.com/results?search_query="+ search_word

print(" 1. 유튜브 접속 및 키워드 검색!!!!!!")
driver.get(url)
time.sleep(0.5)
# Out:
#  1. 유튜브 접속 및 키워드 검색!!!!!!

# %%
print(" 2. Page Down !")

from selenium.webdriver.common.keys import Keys

body = driver.find_element_by_tag_name("body")

for page_down in range(1,10):
    print("page_down = ", page_down)
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1)
# Out:
#  2. Page Down !
# page_down =  1
# page_down =  2
# page_down =  3
# page_down =  4
# page_down =  5
# page_down =  6
# page_down =  7
# page_down =  8
# page_down =  9

# %%
print(" 3. 페이지 html BeautifulSoup 적용 !!!!!!")
from bs4 import BeautifulSoup

#html = driver.page_source  # requests.get 

soup = BeautifulSoup(driver.page_source, "html.parser") # soup
print(" BeautifulSoup 완료!! ")
# Out:
#  3. 페이지 html BeautifulSoup 적용 !!!!!!
#  BeautifulSoup 완료!!

# %%
youtube_base_url = "https://www.youtube.com/"

# 개별 영상 타입 추출 

print(" 4. 개별 영상 타입 추출   !!!!!!")

#3 class="title-and-badge style-scope ytd-video-renderer">
lis = soup.find_all("h3",{"class":"title-and-badge style-scope ytd-video-renderer"})

video_list = []

for video in lis:
    data = video.find("a")["aria-label"]

    len = data.find("게시자")    
    item = data[len:].split()

    channel = item[1]

    title = data[:len-1]
    
    video_url = youtube_base_url+video.find("a")["href"]

    views_count =item[-1]
    upload_date = item[2]+item[3]
   
    video_list.append([channel, title, video_url, views_count, upload_date])
    
# 추출한 list로 dataframe 만들기 
    
import pandas as pd
df_video_item = pd.DataFrame(video_list)

# # 컬럼 만들기
df_video_item.columns = ["채널명","영상제목","영상url","조회수","영상등록날짜"]

print(" 5. 개별영상 타입 완료 = ", df_video_item.shape)

# 재생목록 보기 타입

print(" 6. 재생목록 타입 추출   !!!!!!")

#lis = soup.find_all("h3",{"class":"title-and-badge style-scope ytd-video-renderer"})
lis = soup.find_all("div",{"class":"style-scope ytd-playlist-renderer"})

video_playlist = []

for video in lis:
    channel = video.find("div",{"id":"tooltip"}).text.strip()
    title = video.find("span")["title"]
    play_link = youtube_base_url+video.find("a")["href"]
    
#     print(channel, " * ", title, " * ", play_link )    
    video_playlist.append([channel, title, play_link])
    
# 추출한 list로 dataframe 만들기 
df_video_playlist = pd.DataFrame(video_playlist)

# 컬럼 만들기
df_video_playlist.columns = ["채널명","재생목록제목","재생목록url"]


# 재생목록 영상수 
video_count = soup.find_all("yt-formatted-string",{"class":"style-scope ytd-thumbnail-overlay-side-panel-renderer"})

video_count_list= []
for item in video_count:
    video_count_list.append(item.text)
video_count_list

# 영상수 컬럼 추가 
df_video_playlist["영상수"] = video_count_list

print(" 7. 재생목록  타입 완료 = ", df_video_playlist.shape)
# Out:
#  4. 개별 영상 타입 추출   !!!!!!
#  5. 개별영상 타입 완료 =  (36, 5)
#  6. 재생목록 타입 추출   !!!!!!
#  7. 재생목록  타입 완료 =  (6, 4)

# %%
df_video_item.head(3)
# Out:
#            채널명                                               영상제목  \
# 0  GongbroDesk  파이썬 데이터 분석 - 설치부터 라이브러리 예제까지 (feat. 넘파이, 맷플롯립,...
# 1          데이터  파이썬 판다스로 회사 엑셀데이터 전처리 하는 방법 ! 1탄 (Python / Pan...
# 2  Visualising  무슨 분석 툴을 배워야 할까? - 실제 데이터 과학/데이터 분석 업계에서의 R 과 ...
#
#                                           영상url      조회수   영상등록날짜
# 0  https://www.youtube.com//watch?v=8_VWnRvbGPs  28,790회     7개월전
# 1  https://www.youtube.com//watch?v=3-iwY0_u0VA   5,799회  스테이션5개월
# 2  https://www.youtube.com//watch?v=1e2IjkDYE_8  25,624회  Korea1년

# %%
df_video_playlist.head(3)
# Out:
#                            채널명                  재생목록제목  \
# 0                        한빛미디어   이것이 데이터 분석이다 with 파이썬
# 1  메모밍 채널 ( Channel Memoming )  [Python] 데이터분석을 위한 파이썬
# 2                          동빈나   Python 데이터 분석과 이미지 처리
#
#                                              재생목록url 영상수
# 0  https://www.youtube.com//watch?v=K0YPltIT7jc&l...  21
# 1  https://www.youtube.com//watch?v=XjfUcQk8PiE&l...   9
# 2  https://www.youtube.com//watch?v=V8Lpf3WCZ4g&l...  31

# %% [markdown]
# ### ( type 2 )

# %%
video_list = soup.select('a#video-title')

item = video_list[0]

print("item = ", item.get("aria-label"))
print("link = ", item.get("href"))
# Out:
# item =  파이썬 데이터 분석 - 설치부터 라이브러리 예제까지 (feat. 넘파이, 맷플롯립, 판다스) 게시자: GongbroDesk 7개월 전 10시간 19분 조회수 28,790회
# link =  /watch?v=8_VWnRvbGPs

# %% [markdown]
# ## ( type 3 )

# %%
# 영상 제목 list
title = soup.select(".title-and-badge > #video-title")
title_list = [item["title"] for item in title]

# 채널명 list
channel_name = soup.select("#channel-info #text > a")
channel_list = [item.text for item in channel_name]

# 영상 url list
youtube_url = "https://www.youtube.com/channel"
url_list = [youtube_url + item["href"] for item in channel_name]

# %%
import pandas as pd 

pd.DataFrame({"제목":title_list, 
            "채널명": channel_list,
              "영상url": url_list})
# Out:
#                                                    제목  \
# 0   파이썬 데이터 분석 - 설치부터 라이브러리 예제까지 (feat. 넘파이, 맷플롯립,...
# 1   파이썬 판다스로 회사 엑셀데이터 전처리 하는 방법 ! 1탄 (Python / Pan...
# 2   무슨 분석 툴을 배워야 할까? - 실제 데이터 과학/데이터 분석 업계에서의 R 과 ...
# 3   [1/29] 파이썬 데이터 분석을 위한 Pandas 기초 - 판다스 10분 완성소개...
# 4   Python Pandas 실무 데이터 분석 1탄 (Series / Dataframe...
# 5       [1/5] 파이썬 데이터 분석 - 전국 도시 공원 표준 데이터 불러오기, 요약하기
# 6   [파이썬] 데이터 분석을 위한 파이썬 [08] Pandas (Python for D...
# 7               [통계, 파이썬] 데이터분석 능력 기르기 1. 이건 알고 시작하자.
# 8                 [비전공자를 위한] 파이썬 주식데이터 분석 입문 강의 PART1
# 9                                 데이터 AI 사이언티스트 하지마세요
# 10  데이터 엔지니어 vs 데이터 분석가 vs 데이터 사이언티스트 연봉 KING 전망 K...
# 11                               파이썬으로 주식 예측 2편 수익 공개
# 12            파이썬으로 일상의 데이터를 분석하는 법! 코로나 데이터를 분석해 봐요!
# 13  [매일10분 데이터 분석] 데이터 시각화를 쉽게 해보자 ! (Python / 그래프...
# 14                   25분만에 끝내는 데이터분석, 머신러닝을 위한 기본 파이썬
# 15         파이썬 공공데이터 분석[1/6] - 신규 민간 아파트 분양가격 데이터셋 소개
# 16               [이것이 데이터 분석이다 with 파이썬_11] 시계열 예측 분석
# 17  12-1. 파이썬 데이터 분석 소개 및 csv 파일 데이터 읽어오기 (What is...
# 18     [통계, 파이썬] 데이터분석 능력 기르기 2. 빅데이터의 저주, 파이썬으로 구현하기
# 19  [이것이 데이터 분석이다 with 파이썬_01] 분석 환경 구축하기 주피터 노트북,...
# 20  머신러닝, 데이터분석 공부 고민만 하는 분께 l 파이썬 공부 이유 l 머신러닝 공부 순서
# 21  파이썬 코딩 무료 강의 (활용편3) - 웹 크롤링? 웹 스크래핑! 제가 가진 모든 ...
# 22  [1/7] Python, Pandas,  folium으로 스타벅스, 이디야 매장 위...
# 23          [2/5] 파이썬 데이터 분석 - 주소 및 사용하지 않는 컬럼 결측치 처리
# 24       코딩으로 타이타닉 생존자 예측 프로그램 만들어 보기 [데이터 분석 파이썬 예제]
# 25                  행렬의 필요성 [ Python 데이터 분석과 이미지 처리 ]
# 26           Pandas의 기본 사용법 [ Python 데이터 분석과 이미지 처리 ]
# 27  김도형: 파이썬 데이터 분석 3종 세트 - statsmodels, scikit-le...
# 28  [파이썬] 데이터 분석을 위한 파이썬 [06] 함수와 모듈 (Python for D...
# 29          파이썬 공공데이터 분석[2/6] - Pandas로 데이터 불러오고 요약하기
# 30                        2021년 빅데이터분석기사 필기(파이썬과 R언어)
# 31  [책 리뷰] 파이썬 라이브러리를 활용한 데이터 분석(2판) - Pandas 를 통한...
# 32                [이것이 데이터 분석이다 with 파이썬_10] 연봉 예측 분석
# 33                   빅카인즈 데이터 분석 (1): 파이썬으로 기사 건수 시각화
# 34  [파이썬] 데이터 분석을 위한 파이썬 [01] 변수,  문자열, 파일입출력 (Pyt...
# 35           파이썬으로 함께하는 데이터 분석 강의 | 04-1. 기본 행렬 강의 1편
#
#                             채널명  \
# 0                   GongbroDesk
# 1                      데이터 스테이션
# 2             Visualising Korea
# 3                 todaycode오늘코드
# 4                      데이터 스테이션
# 5                 todaycode오늘코드
# 6   메모밍 채널 ( Channel Memoming )
# 7             Data Scientist이지영
# 8                         사이다경제
# 9                      AI Holic
# 10                   매일경제 에브리데이
# 11            15년차 파이썬 프리랜서 개발자
# 12                온라인 코딩 스쿨 코드잇
# 13                     데이터 스테이션
# 14                         테디노트
# 15                todaycode오늘코드
# 16                        한빛미디어
# 17                    파이썬멘토 조인석
# 18            Data Scientist이지영
# 19                        한빛미디어
# 20               꽃부리 AI With SJ
# 21                         나도코딩
# 22                todaycode오늘코드
# 23                todaycode오늘코드
# 24                        코딩어TV
# 25                          동빈나
# 26                          동빈나
# 27                  PyCon Korea
# 28  메모밍 채널 ( Channel Memoming )
# 29                todaycode오늘코드
# 30                       임베스트TV
# 31                todaycode오늘코드
# 32                        한빛미디어
# 33                Geoinfo Study
# 34  메모밍 채널 ( Channel Memoming )
# 35                    제주코딩베이스캠프
#
#                                                 영상url
# 0   https://www.youtube.com/channel/channel/UCo82I...
# 1   https://www.youtube.com/channel/channel/UCyc4x...
# 2   https://www.youtube.com/channel/channel/UCbBev...
# 3   https://www.youtube.com/channel/channel/UCLR3s...
# 4   https://www.youtube.com/channel/channel/UCyc4x...
# 5   https://www.youtube.com/channel/channel/UCLR3s...
# 6   https://www.youtube.com/channel/channel/UCd2xY...
# 7   https://www.youtube.com/channel/channel/UC2Bre...
# 8   https://www.youtube.com/channel/channel/UC-if2...
# 9     https://www.youtube.com/channel/user/ChrissSong
# 10  https://www.youtube.com/channel/channel/UCIipm...
# 11  https://www.youtube.com/channel/channel/UCrUBl...
# 12  https://www.youtube.com/channel/channel/UCCM79...
# 13  https://www.youtube.com/channel/channel/UCyc4x...
# 14  https://www.youtube.com/channel/channel/UCt2wA...
# 15  https://www.youtube.com/channel/channel/UCLR3s...
# 16  https://www.youtube.com/channel/user/HanbitMed...
# 17      https://www.youtube.com/channel/user/kakigo4u
# 18  https://www.youtube.com/channel/channel/UC2Bre...
# 19  https://www.youtube.com/channel/user/HanbitMed...
# 20  https://www.youtube.com/channel/channel/UCUdyx...
# 21  https://www.youtube.com/channel/channel/UC7iAO...
# 22  https://www.youtube.com/channel/channel/UCLR3s...
# 23  https://www.youtube.com/channel/channel/UCLR3s...
# 24  https://www.youtube.com/channel/channel/UCFDIM...
# 25  https://www.youtube.com/channel/channel/UChflh...
# 26  https://www.youtube.com/channel/channel/UChflh...
# 27  https://www.youtube.com/channel/channel/UC26x6...
# 28  https://www.youtube.com/channel/channel/UCd2xY...
# 29  https://www.youtube.com/channel/channel/UCLR3s...
# 30  https://www.youtube.com/channel/channel/UChcuZ...
# 31  https://www.youtube.com/channel/channel/UCLR3s...
# 32  https://www.youtube.com/channel/user/HanbitMed...
# 33  https://www.youtube.com/channel/channel/UClhOy...
# 34  https://www.youtube.com/channel/channel/UCd2xY...
# 35  https://www.youtube.com/channel/channel/UC4Gnv...

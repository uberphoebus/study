# %% [markdown]
# ## ( 실습 )
# 1. 네이버 뉴스 속보 수집
#   -날짜, page 구분
#   -날짜 ..8월 3일 8월 4일 데이터
#   -날짜별 page =3page (1,2,3,)
# 2. get_page() 함수 만들기
#    - input ->  url을 입력받아서
#    - output -> dl
# 3. page_to_items() 함수 만들기
#    - input -> dl
#    - output -> news_page list를 Return
# 4. news_page로 DataFrame 만들기 -> news_df
#    - ["날짜","이미지링크","기사링크,"기사제목","기사내용"]
# 5. DataFrame에서 csv 만들기 -> news_df.csv

# %%
## 네이버 뉴스 속보를 수집 
import requests 
from bs4 import BeautifulSoup 
headers = { "User-Agent":"Mozilla/5.0"}

def get_page(url):    
    html = requests.get(url, headers=headers)
    soup = BeautifulSoup(html.text)  # "html.parser"  
    type06 = soup.find("ul",{"class":"type06_headline"})
    dl = type06.find_all("dl")
    return dl

def page_to_items(dl):
    news_page = []

    for item2 in dl:
        try:
            # 기사 이미지 
            img = item2.find("dt",{"class":"photo"}).find("img")
            img_src = img["src"]      
            # 기사 링크, 타이틀 
            link = item2.find("dt", {"class":""}).find("a")
            link_href = link["href"]        
            link_text =link.text.replace("\t","").replace("\r\n","").strip()     
            # 기사 내용 
            content = item2.find("dd")
            content_text = content.text.replace("\n","").split("…")[0] 

            news_page.append([img_src, link_href, link_text, content_text])

        except: 
            print("No Image or No Contents!! ")
    return news_page

url = "https://news.naver.com/main/list.nhn?mode=LSD&mid=sec&sid1=001"
get_dl = get_page(url) 
news_page = page_to_items(get_dl)

# df 만들기 
import pandas as pd
news_df = pd.DataFrame(news_page, 
                      columns = ["이미지링크","기사링크","기사제목","기사내용"])

# csv 만들기 
news_df.to_csv("c:/jswoo/naver_news.csv", index=False)
pd.read_csv("c:/jswoo/naver_news.csv").head(3)
# Out:
# No Image or No Contents!!
#                                                이미지링크  \
# 0  https://imgnews.pstatic.net/image/origin/011/2...
# 1  https://imgnews.pstatic.net/image/origin/031/2...
# 2  https://imgnews.pstatic.net/image/origin/018/2...
#
#                                                 기사링크  \
# 0  https://news.naver.com/main/read.naver?mode=LS...
# 1  https://news.naver.com/main/read.naver?mode=LS...
# 2  https://news.naver.com/main/read.naver?mode=LS...
#
#                                 기사제목  \
# 0        흔들리는 한미연합훈련···美 “중단 요청 없었다”
# 1           경북 영덕군, 저소득층 추가 국민지원금 지급
# 2  TS트릴리온, 오는 6일 'TS퍼퓸샴푸' 쿠팡 골드박스 선봬
#
#                                                 기사내용
# 0  [서울경제] 한미연합군사훈련을 두고 통일부·국정원 등에서 연기를 요구하고 나선 가운...
# 1  경북 영덕군은 '저소득층 추가 국민지원금' 신청을 받는다고 4일 밝혔다. 군은 오는...
# 2  [이데일리 이윤정 인턴기자] 샴푸 브랜드 ‘TS샴푸’ 캠페인을 전개하고 있는 TS트...

# %% [markdown]
# ### ( 참고.  python 교육콘텐츠 )

# %%
## 변수에 값 할당
## 변수이름 = 값 
temp = 2

# %%
temp
# Out:
# 2

# %%
print(temp)
# Out:
# 2

# %% [markdown]
# ### ( 변수이름 부여 규칙 )
# 1. 변수명 = 값(함수.. 객체...)
# 2. 변수 이름은?
#    - 영문대(A-Z), 소문자(a-z), 숫자(0~9), _
#    - 단, 숫자가 맨 처음에 오면 안됨..

# %%
temp = 1

# %%
1temp = 22
# Out:
#   File "<ipython-input-5-6e82147aebdb>", line 1
#     1temp = 22
#      ^
# SyntaxError: invalid syntax

# %%
temp1 = 22

# %%
te1mp = 33

# %%
te1_m_p = 44

# %%
TeMp1_3 = 55

# %%
# 사칙연산 
a = 7 ; b = 3

# %%
import keyword 
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a = 7 ; b = 3 
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 10
# 4
# 21
# 2.3333333333333335

# %%
type(a)
# Out:
# int

# %%
print(a//b)
# Out:
# 2

# %%
print(a%b)
# Out:
# 1

# %%
a = 10
print(a%b)
# Out:
# 1

# %%
a
b
# Out:
# 3

# %%
print(a);print(b)
# Out:
# 10
# 3

# %%
for i in range(0,50):
    if i%10 == 0:
        print("i = ", i)
# Out:
# i =  0
# i =  10
# i =  20
# i =  30
# i =  40

# %%
print("a+b = ", a+b)
print("a-b = {}".format(a-b))
print("a*b = {} * {} = {}".format(a,b,a*b))
print("a/b = %d / %d = %f"%(a,b,a/b))
# Out:
# a+b =  13
# a-b = 7
# a*b = 10 * 3 = 30
# a/b = 10 / 3 = 3.333333

# %%
print("a*b = {1} * {0} = {2}".format(a,b,a*b))
# Out:
# a*b = 3 * 10 = 30

# %%
a + "1"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-23f493086f83> in <module>
# ----> 1 a + "1"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a + int("1")
# Out:
# 11

# %%
a
# Out:
# 10

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %% [markdown]
# ### ( 문자열 )

# %%
temp = "python is easy "  # 'python is easy'

# %%
temp
# Out:
# 'python is easy '

# %%
print(temp)
# Out:
# python is easy

# %%
temp = "python is easy"

# %%
len(temp)
# Out:
# 14

# %%
'python' + 'is easy'
# Out:
# 'pythonis easy'

# %%
'python ' + 'is easy'
# Out:
# 'python is easy'

# %%
a = 'python ' ; b='is easy'
a + b
# Out:
# 'python is easy'

# %%
## index[]
temp
# Out:
# 'python is easy'

# %%
temp[3]
# Out:
# 'h'

# %%
temp[0:5]
# Out:
# 'pytho'

# %%
st = 0; en= 5
temp[st:en] # temp[0:5]
# Out:
# 'pytho'

# %%
temp[:]
# Out:
# 'python is easy'

# %%
temp[3:]
# Out:
# 'hon is easy'

# %%
temp[:-3]
# Out:
# 'python is e'

# %%
temp[::2]
# Out:
# 'pto ses'

# %%
temp # is
# Out:
# 'python is easy'

# %%
temp[7:9]
# Out:
# 'is'

# %%
type(temp)
# Out:
# str

# %%
temp
# Out:
# 'python is easy'

# %%
temp.split()
# Out:
# ['python', 'is', 'easy']

# %%
a = 1

# %%
a.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-d951bd4a63fe> in <module>
# ----> 1 a.split()
#
# AttributeError: 'int' object has no attribute 'split'

# %%
temp2 = 'python,java,R,SAS'
temp2
# Out:
# 'python,java,R,SAS'

# %%
temp2.split(",")
# Out:
# ['python', 'java', 'R', 'SAS']

# %%
bb = "localhost:8888/notebooks/0.jswoo/210726_기초문법_자료형.ipynb"

# %%
aa = "localhost:8888/notebooks/0.jswoo/210726_기초문법_자료형.ipynb"

# %%
aa
# Out:
# 'localhost:8888/notebooks/0.jswoo/210726_기초문법_자료형.ipynb'

# %%
aa.split("/")
# Out:
# ['localhost:8888', 'notebooks', '0.jswoo', '210726_기초문법_자료형.ipynb']

# %%
aa.split("/")[-1]
# Out:
# '210726_기초문법_자료형.ipynb'

# %%
temp2.split(",")
# Out:
# ['python', 'java', 'R', 'SAS']

# %%
temp3 = temp2.split(",")

# %%
temp3
# Out:
# ['python', 'java', 'R', 'SAS']

# %%
",".join(temp3)
# Out:
# 'python,java,R,SAS'

# %%
a1 = 1; a2=2; a3=3; a4=4

# %%
print(a2)
# Out:
# 2

# %% [markdown]
# ### ( 데이터 구조 )
# 1. 리스트
# 2. 튜플
# 3. 딕셔너리

# %%
## ( 리스트 ) 
num = ['one','two','three','four']
print(num)
# Out:
# ['one', 'two', 'three', 'four']

# %%
type(num)
# Out:
# list

# %%
type(num[0])
# Out:
# str

# %%
num1 = [1,2,3,4,5]
num1
# Out:
# [1, 2, 3, 4, 5]

# %%
type(num1[0])
# Out:
# int

# %%
num_t = ('one','two','three','four');num_t
# Out:
# ('one', 'two', 'three', 'four')

# %%
list(num_t)
# Out:
# ['one', 'two', 'three', 'four']

# %%
num3 = list(num_t)

# %%
num
# Out:
# ['one', 'two', 'three', 'four']

# %%
aa = 1

# %%
list(aa)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-5095cb5757fc> in <module>()
# ----> 1 list(aa)
#
# TypeError: 'int' object is not iterable

# %%
bb = 'abcde'
list(bb)

# %%
num

# %%
num[1]

# %%
num[2:4]

# %%
num[5:7]

# %%
num[7]

# %%
len(num)

# %%
num[0] = "first" ; num

# %%
num

# %%
num.append("five"); num

# %%
new = []

# %%
new.append(1)

# %%
new.append(2)

# %%
new.append("3")

# %%
new

# %%
del num[1] ; num

# %%
num

# %%
num.remove("three") ; num

# %%
num3

# %%
num4 = [6,7,8,9]

# %%
num3.extend(num4)

# %%
num3

# %%
num4.extend(num3)

# %%
num5 = sorted(num3)
num5

# %%
num4

# %%
num=['one','two','three','four'];num

# %%
sorted(num)

# %%
num5 = sorted(num);num5

# %%
num1.sort(reverse=True);num1

# %%
num1.sort();num1

# %%
len(num)

# %%
num

# %%
len(num[2])

# %%
dir(num)

# %% [markdown]
# ### ( 튜플 )

# %%
tup = ("a","b","c","d");tup
# Out:
# ('a', 'b', 'c', 'd')

# %%
tup[1]
# Out:
# 'b'

# %%
tup[1] = "z"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-165-ba6d7c9f2f8a> in <module>
# ----> 1 tup[1] = "z"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### ( 딕셔너리 )
# 1. key - value
# 2. {key1:value1, key2:value...}
#    - value -> 문자,숫자,리스트...

# %%
fruit = {'cherry':5000, 'peer':2500, 'apple':3500}
fruit
# Out:
# {'cherry': 5000, 'peer': 2500, 'apple': 3500}

# %%
fruit1 = {'che':[5000,3], 'pee':[2500,2], 'app':[3500,10]}
fruit1
# Out:
# {'che': [5000, 3], 'pee': [2500, 2], 'app': [3500, 10]}

# %%
fruit2 = [['apple',3500],['peer',2500],['cherry',5000]]
fruit2
# Out:
# [['apple', 3500], ['peer', 2500], ['cherry', 5000]]

# %%
dict(fruit)
# Out:
# {'cherry': 5000, 'peer': 2500, 'apple': 3500}

# %%
fruit3 = [['apple',3500],['peer',[2500,3]],['cherry',5000]]

# %%
fruit4 = dict(fruit3)

# %%
fruit.keys()
# Out:
# dict_keys(['cherry', 'peer', 'apple'])

# %%
fruit['peer']
# Out:
# 2500

# %%
fruit4['peer']
# Out:
# [2500, 3]

# %%
fruit4
# Out:
# {'apple': 3500, 'peer': [2500, 3], 'cherry': 5000}

# %%
fruit3[1][1]
# Out:
# [2500, 3]

# %%
fruit4['peer']
# Out:
# [2500, 3]

# %%
fruit.get('peer')
# Out:
# 2500

# %%
fruit
# Out:
# {'cherry': 5000, 'peer': 2500, 'apple': 3500}

# %%
fruit.keys()
# Out:
# dict_keys(['cherry', 'peer', 'apple'])

# %%
fruit.values()
# Out:
# dict_values([5000, 2500, 3500])

# %%
fruit.items()
# Out:
# dict_items([('cherry', 5000), ('peer', 2500), ('apple', 3500)])

# %%
a = 7

# %%
a = 7

# %%
abc = 7

# %%
a b = 7
# Out:
#   File "<ipython-input-206-65fb769d776e>", line 1
#     a b = 7
#       ^
# SyntaxError: invalid syntax

# %%
a , b = 7,3

# %%
print("a = ", a)
print("b = ", b)
# Out:
# a =  7
# b =  3

# %%
a_b

# %%
lambda_1 = 1

# %%
for = 1
# Out:
#   File "<ipython-input-211-b26be1b49601>", line 1
#     for = 1
#         ^
# SyntaxError: invalid syntax

# %%
tup
# Out:
# ('a', 'b', 'c', 'd')

# %%
tup[2]
# Out:
# 'c'

# %%
del tup[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-215-c7888f99c820> in <module>
# ----> 1 del tup[2]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
tup1 = (1,2,3,4)

# %%
tup1 = 1,2,3,4

# %%
tup1
# Out:
# (1, 2, 3, 4)

# %%
tup1 = (1)

# %%
tup1
# Out:
# 1

# %%
tup2 = (1,)

# %%
tup2
# Out:
# (1,)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts
# Out:
# 2000-01-01    0.198607
# 2000-01-02   -1.721871
# 2000-01-03   -0.621436
# 2000-01-04    0.645959
# 2000-01-05   -0.572430
#                 ...
# 2002-09-22   -1.157656
# 2002-09-23   -0.547299
# 2002-09-24    0.174024
# 2002-09-25   -1.015149
# 2002-09-26   -0.591527
# Freq: D, Length: 1000, dtype: float64

# %%
ts = ts.cumsum()
ts
# Out:
# 2000-01-01       2.051642
# 2000-01-02       4.102015
# 2000-01-03       7.095610
# 2000-01-04       9.427065
# 2000-01-05      12.130789
#                  ...
# 2002-09-22    2533.114556
# 2002-09-23    2549.358478
# 2002-09-24    2565.954793
# 2002-09-25    2582.627679
# 2002-09-26    2599.849432
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot();

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01  0.534478  0.381166  1.724263 -0.242762
# 2000-01-02 -1.956008  0.841733 -2.133489 -1.371245
# 2000-01-03  0.743240  1.007958  0.118086  0.862333
# 2000-01-04 -0.057462 -0.388612 -0.036691 -0.441382
# 2000-01-05 -0.322768 -0.043388 -0.505866  0.532235
# ...              ...       ...       ...       ...
# 2002-09-22 -0.615282 -0.484522  1.264971  2.082354
# 2002-09-23 -0.412047 -0.406285  0.623642 -1.765595
# 2002-09-24  0.855989  0.003575 -0.379856 -0.517493
# 2002-09-25  0.828133 -0.875693  0.279588  0.525701
# 2002-09-26 -0.821432 -0.300351 -2.364598 -1.519603
#
# [1000 rows x 4 columns]

# %%
df = df.cumsum()
df
# Out:
#                        A             B           C             D
# 2000-01-01      0.534478      0.381166    1.724263     -0.242762
# 2000-01-02     -0.887053      1.604065    1.315037     -1.856770
# 2000-01-03     -1.565344      3.834922    1.023897     -2.608444
# 2000-01-04     -2.301097      5.677168    0.696066     -3.801501
# 2000-01-05     -3.359618      7.476025   -0.137631     -4.462323
# ...                  ...           ...         ...           ...
# 2002-09-22 -11976.935960  17553.631986 -257.579491  21531.271384
# 2002-09-23 -11982.771564  17582.911469 -250.822223  21565.874663
# 2002-09-24 -11987.751179  17612.194527 -244.444812  21599.960449
# 2002-09-25 -11991.902661  17640.601891 -237.787813  21634.571936
# 2002-09-26 -11996.875575  17668.708905 -233.495412  21667.663821
#
# [1000 rows x 4 columns]

# %%
plt.figure();

# %%
df.plot();

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()

# %%
df3["A"] = pd.Series(list(range(len(df))))
df3
# Out:
#             B          C    A
# 0    0.863039  -1.187919    0
# 1   -0.085815  -0.532305    1
# 2    0.733131  -1.945662    2
# 3    0.707680  -4.219438    3
# 4    0.706909  -3.201262    4
# ..        ...        ...  ...
# 995  4.875117  53.772336  995
# 996  4.181851  54.077512  996
# 997  3.960333  53.675564  997
# 998  3.588400  52.027453  998
# 999  2.459768  51.719661  999
#
# [1000 rows x 3 columns]

# %%
df3.plot(x="A", y="B");
df3.plot

# %%
plt.figure();

# %%
df.iloc[5].plot(kind="bar");

# %%
df = pd.DataFrame()

# %%
 df.plot
df.plot.area,df.plot.barh,df.plot.density, df.plot.hist, df.plot.line, df.plot.scatter,
df.plot.bar, df.plot.box, df.plot.hexbin, df.plot.kde, df.plot.pie

# %%
plt.figure();

# %%
plt.axhline(0, color="k");

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])

# %%
df2
# Out:
#           a         b         c         d
# 0  0.499648  0.776987  0.486428  0.799628
# 1  0.386604  0.445702  0.140178  0.334642
# 2  0.508117  0.614794  0.809881  0.422791
# 3  0.418179  0.466786  0.158869  0.393218
# 4  0.322798  0.685362  0.976699  0.095519
# 5  0.118554  0.912725  0.232350  0.388648
# 6  0.252994  0.776406  0.996681  0.140136
# 7  0.733271  0.593588  0.496721  0.714375
# 8  0.670087  0.345567  0.406907  0.004401
# 9  0.757634  0.698233  0.848270  0.795597

# %%
df2.plot.bar();

# %%
df2.plot.barh(stacked=True);

# %%
df2.plot.barh(stacked=False);

# %%
df4 = pd.DataFrame(
{
       "a": np.random.randn(1000) + 1,
     "b": np.random.randn(1000),
       "c": np.random.randn(1000) - 1,
    },
    columns=["a", "b", "c"],
)

# %%
df4
# Out:
#             a         b         c
# 0    1.956343  0.431523 -0.473387
# 1    2.892603 -0.420868 -1.660713
# 2    1.574209  0.404571 -1.650426
# 3    1.123510  1.590819 -0.625418
# 4   -0.140433 -1.767063 -1.275949
# ..        ...       ...       ...
# 995  0.897693  0.804789 -1.819273
# 996  0.532079 -0.001002 -2.963828
# 997  2.138305 -0.253597 -1.710571
# 998  1.274800 -1.482683 -0.724689
# 999  0.884827 -0.044133 -1.529762
#
# [1000 rows x 3 columns]

# %%
plt.figure();

# %%
df4.plot.hist(alpha=0.5);

# %%
df4.plot.hist(stacked=True, bins=20);

# %%
df4["a"].plot.hist(orientation="horizontal", cumulative=True);

# %%
data = pd.Series(np.random.randn(1000))
data
# Out:
# 0      1.266904
# 1     -0.425605
# 2     -0.943244
# 3     -0.901552
# 4     -1.985242
#          ...
# 995   -0.451195
# 996   -0.697447
# 997   -0.139141
# 998   -0.762462
# 999    0.264666
# Length: 1000, dtype: float64

# %%
data.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4));

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])

# %%
df.plot.box();

# %%
df = pd.DataFrame(np.random.rand(10, 5))
bp = df.boxplot()

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=["Col1", "Col2"])
df["X"] = pd.Series(["A", "A", "A", "A", "A", "B", "B", "B", "B", "B"])
bp = df.boxplot(by="X")

# %%
df = pd.DataFrame(np.random.rand(10, 3), columns=["Col1", "Col2", "Col3"])

# %%
pd.Series(["A", "A", "A", "A", "A", "B", "B", "B", "B", "B"])
# Out:
# 0    A
# 1    A
# 2    A
# 3    A
# 4    A
# 5    B
# 6    B
# 7    B
# 8    B
# 9    B
# dtype: object

# %%
pd.Series(["A", "B", "A", "B", "A", "B", "A", "B", "A", "B"])
# Out:
# 0    A
# 1    B
# 2    A
# 3    B
# 4    A
# 5    B
# 6    A
# 7    B
# 8    A
# 9    B
# dtype: object

# %%
np.random.seed(1234)
df_box = pd.DataFrame(np.random.randn(50, 2))
df_box["g"] = np.random.choice(["A", "B"], size=50)
df_box.loc[df_box["g"] == "B", 1] += 3
bp = df_box.boxplot(by="g")

# %%
bp = df_box.groupby("g").boxplot()

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df.plot.area();

# %%
df.plot.area(stacked=False);

# %%
df.plot.scatter(x="a", y="b", c="c", s=50);

# %%
df.plot.scatter(x="a", y="b", s=df["c"] * 200);

# %%
 df = pd.DataFrame(
3 * np.random.rand(4, 2), index=["a", "b", "c", "d"], columns=["x", "y"]
)


In [81]: df.plot.pie(subplots=True, figsize=(8, 4));

# %%
series = pd.Series([0.1] * 4, index=["a", "b", "c", "d"], name="series2")
series.plot.pie(figsize=(6, 6));
# Out:
# C:\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)

# %%
ser = pd.Series(np.random.randn(1000))
ser.plot.kde();

# %%
from pandas.plotting import lag_plot

# %%
plt.figure();

# %%
spacing = np.linspace(-99 * np.pi, 99 * np.pi, num=1000)

# %%
data = pd.Series(0.1 * np.random.rand(1000) + 0.9 * np.sin(spacing))

# %%
lag_plot(data);

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
# Out:
#   File "<ipython-input-99-2e9e619535c3>", line 2
#     df = df.cumsum()
#     ^
# IndentationError: unexpected indent

# %%
df = df.cumsum()

# %%
df.plot(legend=False);

# %%
df.plot();

# %%
df.plot(xlabel="new x", ylabel="new y");

# %%
df.plot(subplots=True, figsize=(6, 6));

# %%
df.plot(subplots=True, layout=(2, 3), figsize=(6, 6), sharex=False);

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 6.5))

# %%
df = pd.DataFrame(np.random.rand(5, 3), columns=["a", "b", "c"])

# %%
ax.xaxis.tick_top()  # Display x-axis ticks on top.

# %%
df.plot(table=True, ax=ax);

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 6.75))
ax.xaxis.tick_top()
df.plot(table=np.round(df.T, 2), ax=ax);

# %%
from pandas.plotting import table
fig, ax = plt.subplots(1, 1)
table(ax, np.round(df.describe(), 2), loc="upper right", colWidths=[0.2, 0.2, 0.2]);
df.plot(ax=ax, ylim=(0, 2), legend=None);

# %%
from matplotlib import cm
plt.figure();
df.plot(colormap=cm.cubehelix);

# %%
df = pd.DataFrame(np.random.randn(1000, 10), index=ts.index)
df = df.cumsum()
plt.figure();
df.plot(colormap="cubehelix");

# %%
from matplotlib import cm
plt.figure();
df.plot(colormap=cm.cubehelix);

# %%
dd = pd.DataFrame(np.random.randn(10, 10)).applymap(abs)
dd = dd.cumsum()
plt.figure();
dd.plot.bar(colormap="Greens");

# %%
plt.figure();
